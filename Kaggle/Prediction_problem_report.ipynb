# %% [raw]
# ---
# title: "Prediction problems: Report"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     toc-depth: 4
#     code-fold: show
#     self-contained: true
#     html-math-method: mathml
# jupyter: python3
# ---

# %% [markdown]
# ## Instructions {-}
#
# 1. This is the template you may use to submit your code and report for the prediction problems on Kaggle.
#
# 2. You may modify the template if you deem fit, but it should have the information asked below.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error,r2_score,roc_curve,auc,  confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, ParameterGrid, RandomizedSearchCV, cross_val_score, train_test_split, KFold
from sklearn.ensemble import  StackingRegressor, VotingRegressor, BaggingRegressor,BaggingClassifier,RandomForestRegressor,RandomForestClassifier, AdaBoostRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression,  Lasso, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler, FunctionTransformer, StandardScaler
from sklearn.impute import KNNImputer
from sklearn.decomposition import PCA
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import ElasticNetCV
import itertools as it
import xgboost as xgb
import lightgbm as lgb
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from pyearth import Earth
import time as time

# %% [markdown]
# ## A.1) Data cleaning

# %% [markdown]
# Mention the data cleaning steps taken to prepare your data for developing the model. This may include imputing missing values, dealing with outliers, combining levels of categorical variable(s), etc.

# %% [markdown]
# * Put your data cleaning/preparation code with comments here
# * The code should begin from reading the train data
# * The code should end when you obtain the data used to develop the model in A.4

# %%
# Read train and test data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# Pull id of test rows to be used later
test_id = test.id

# Drop id column
train = train.drop(columns = 'id')
test = test.drop(columns = 'id')

# Define X, y, and X_test
X = train.drop(columns = 'y')
y = train['y']
X_test = test 

# Standardize train and test data
sc = StandardScaler()
sc.fit(X)
X_train = sc.transform(X)
X_test = sc.transform(X_test)

# Imputing missing values
imputer = KNNImputer(n_neighbors=10)
X_train = pd.DataFrame(imputer.fit_transform(X_train),columns = X.columns)
X_test = pd.DataFrame(imputer.fit_transform(X_test),columns = test.columns)

# Log y
log_y = np.log(y)

# %% [markdown]
# ## A.2) Exploratory data analysis

# %% [markdown]
# Mention any major insights you obtained from the data, which you used to develop the model. PLease put your code or visualizations here if needed.
#
# - Insight 1
# - Insight 2
# - .........

# %% [markdown]
# I performed plentiful EDA, which included exploring the null values, outliers, multicollinearity, and PCA. However, none of this EDA really ended up being that helpful in creating the best model. I initially thought reducing the dimensionality of the dataset would be useful, but in the end, it really came down to trying different combinations of models, which you will see in the rest of this report.

# %% [markdown]
# ## A.3) Feature selection/reduction

# %% [markdown]
# Mention the steps for feature selection/reduction. PLease put your code or visualizations here if needed.
#
# - step 1
# - step 2
# - .........

# %% [markdown]
# ### CatBoost (for feature reduction)

# %% [markdown]
# Step 1: train default CatBoost model on entire dataset

# %%
cat_base = CatBoostRegressor()
cat_base.fit(X_train, log_y, verbose=False)

# %% [markdown]
# Step 2: remove features from dataset that had 0 importance in CatBoost model

# %%
# Get the feature importances from the CatBoost model
cat_feature_importances = cat_base.feature_importances_

# Create a DataFrame to store the feature names and importances
cat_feature_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': cat_feature_importances})

# Sort the DataFrame by feature importances in descending order
cat_sorted_features = cat_feature_df.sort_values(by='Importance', ascending=False)

# %%
# Check feature importances
cat_sorted_features[:649]
# Out:
#     Feature  Importance
# 701    x702    5.472942
# 104    x105    4.259369
# 566    x567    4.101641
# 145    x146    2.046978
# 117    x118    1.718619
# ..      ...         ...
# 169    x170    0.003143
# 311    x312    0.003062
# 763    x764    0.002961
# 438    x439    0.002726
# 665    x666    0.001836
#
# [649 rows x 2 columns]

# %%
# Take the top X features
cat_top_features = cat_sorted_features.head(649)

# Get the feature names as a list
cat_top_feature_names = cat_top_features['Feature'].tolist()

# Filter the train and test data using the top feature names
cat_X_train_filtered = X_train[cat_top_feature_names]
cat_X_test_filtered = X_test.loc[:,cat_X_train_filtered.columns]

# %% [markdown]
# Step 3: train default model on filtered dataset

# %%
cat = CatBoostRegressor()
cat.fit(cat_X_train_filtered, log_y, verbose=False)

# %% [markdown]
# Step 4: remove non-important features once again

# %%
# Get the feature importances from the CatBoost model
cat_feature_importances_2 = cat.feature_importances_

# Create a DataFrame to store the feature names and importances
cat_feature_df_2 = pd.DataFrame({'Feature': cat_X_train_filtered.columns, 'Importance': cat_feature_importances_2})

# Sort the DataFrame by feature importances in descending order
cat_sorted_features_2 = cat_feature_df_2.sort_values(by='Importance', ascending=False)

# %%
cat_sorted_features_2[:607]
# Out:
#     Feature  Importance
# 0      x702    5.292004
# 1      x105    4.598000
# 2      x567    4.248394
# 9      x102    2.511596
# 6      x670    1.965405
# ..      ...         ...
# 553    x254    0.004488
# 488    x237    0.003348
# 634    x069    0.003284
# 538    x313    0.002926
# 516    x095    0.002889
#
# [607 rows x 2 columns]

# %%
# Take the top X features
cat_top_features_2 = cat_sorted_features_2.head(607)

# Get the feature names as a list
cat_top_feature_names_2 = cat_top_features_2['Feature'].tolist()

# Filter the training data using the top feature names
cat_X_train_filtered_2 = cat_X_train_filtered[cat_top_feature_names_2]

cat_X_test_filtered_2 = cat_X_test_filtered.loc[:,cat_X_train_filtered_2.columns]

# %% [markdown]
# ### MARS (for feature reduction)

# %% [markdown]
# Step 1: train MARS on entire train dataset

# %%
mars = Earth(max_degree = 1, feature_importance_type = 'rss')
mars.fit(X_train, log_y)
# Out:
# C:\Users\rolfe\anaconda3\lib\site-packages\pyearth\earth.py:813: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   pruning_passer.run()
# C:\Users\rolfe\anaconda3\lib\site-packages\pyearth\earth.py:1066: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   coef, resid = np.linalg.lstsq(B, weighted_y[:, i])[0:2]
# Earth(feature_importance_type='rss', max_degree=1)

# %% [markdown]
# Step 2: Check most important features of MARS model

# %%
# Retrieve the feature importances
mars_feature_importances = mars.feature_importances_

# Retrieve the feature names 
feature_names = X_train.columns

# Sort the feature names based on importances
mars_sorted_indices = np.argsort(mars_feature_importances)[::-1]
mars_sorted_feature_names = [feature_names[i] for i in mars_sorted_indices]
mars_sorted_importances = mars_feature_importances[mars_sorted_indices]

# Create an array with feature names and importances in order
mars_feature_importances_array = np.column_stack((mars_sorted_feature_names, mars_sorted_importances))

# %%
mars_feature_importances_array[:21]
# Out:
# array([['x102', '0.3688501777512344'],
#        ['x118', '0.26081660159946174'],
#        ['x174', '0.0950616792231861'],
#        ['x253', '0.08579451113222046'],
#        ['x337', '0.03754954121775787'],
#        ['x567', '0.030405954505762188'],
#        ['x355', '0.02414998260861697'],
#        ['x105', '0.017977164800277192'],
#        ['x218', '0.0168931035702206'],
#        ['x092', '0.012819683876068367'],
#        ['x265', '0.011986861462570298'],
#        ['x286', '0.009458921602312494'],
#        ['x420', '0.00905861059359245'],
#        ['x111', '0.007339808440261188'],
#        ['x321', '0.004961874311978705'],
#        ['x667', '0.0018224337499960486'],
#        ['x733', '0.0016584939187161709'],
#        ['x527', '0.0016222828346693404'],
#        ['x106', '0.0012873259351471695'],
#        ['x154', '0.0004849868659502246'],
#        ['x211', '0.0']], dtype='<U32')

# %% [markdown]
# Step 3: Define new training dataset with only MARS model important features

# %%
X_train_mars = X_train[mars_sorted_feature_names[:21]]
X_test_mars = X_test.loc[:,X_train_mars.columns]

# %% [markdown]
# ## A.4) Developing the model

# %% [markdown]
# Mention the logical sequence of steps taken to obtain the final model.
#
# - Model 1
# - Model 2
# - .........

# %% [markdown]
# ### CatBoost

# %% [markdown]
# Train tuned CatBoost model on new filtered dataset (tuned using RandomizedSearchCV and on original training dataset)

# %%
cat = CatBoostRegressor(iterations = 750,
                        depth = 6,
                        l2_leaf_reg = 4,
                        border_count = 256,
                        learning_rate = 0.08,
                        random_state = 1)
cat.fit(cat_X_train_filtered_2, log_y, verbose=False)

# %% [markdown]
# ### Light GBM

# %% [markdown]
# Train tuned Light GBM model on MARS feature importance dataset (tuned using RandomizedSearchCV and on that same MARS training dataset)

# %%
lgbm = LGBMRegressor(
    objective = 'regression',
    n_estimators = 1200,
    num_leaves=15,
    learning_rate=0.01,
    colsample_bytree=0.6,
    subsample = 1.0,
    reg_lambda = 0,
    reg_alpha = 0,
    max_depth = 9
)

# Train the LGBMRegressor model
lgbm.fit(X_train_mars, log_y)
# Out:
# LGBMRegressor(colsample_bytree=0.6, learning_rate=0.01, max_depth=9,
#               n_estimators=1200, num_leaves=15, objective='regression',
#               reg_alpha=0, reg_lambda=0)

# %% [markdown]
# ### Ensemble

# %% [markdown]
# Ensemble Catboost and Light GBM models, trained on entire original training dataset

# %%
#Stacking using ElasticNetCV as the meta-model
en=StackingRegressor(estimators = [('cat',cat),('lgbm',lgbm)],
                     final_estimator=ElasticNetCV(),
                     cv = KFold(n_splits = 5, shuffle = True))
en.fit(X_train,log_y)
# Out:
# 0:	learn: 0.9763003	total: 95.2ms	remaining: 1m 11s
# 1:	learn: 0.9573929	total: 152ms	remaining: 56.9s
# 2:	learn: 0.9393380	total: 209ms	remaining: 52s
# 3:	learn: 0.9237356	total: 267ms	remaining: 49.9s
# 4:	learn: 0.9078259	total: 336ms	remaining: 50s
# 5:	learn: 0.8937153	total: 399ms	remaining: 49.4s
# 6:	learn: 0.8798322	total: 472ms	remaining: 50.1s
# 7:	learn: 0.8671812	total: 543ms	remaining: 50.4s
# 8:	learn: 0.8572035	total: 622ms	remaining: 51.2s
# 9:	learn: 0.8485108	total: 693ms	remaining: 51.2s
# 10:	learn: 0.8395626	total: 766ms	remaining: 51.5s
# 11:	learn: 0.8320192	total: 834ms	remaining: 51.3s
# 12:	learn: 0.8236551	total: 896ms	remaining: 50.8s
# 13:	learn: 0.8156931	total: 959ms	remaining: 50.4s
# 14:	learn: 0.8092155	total: 1.03s	remaining: 50.5s
# 15:	learn: 0.8028273	total: 1.09s	remaining: 50.2s
# 16:	learn: 0.7975328	total: 1.16s	remaining: 49.9s
# 17:	learn: 0.7912517	total: 1.22s	remaining: 49.5s
# 18:	learn: 0.7857633	total: 1.28s	remaining: 49.4s
# 19:	learn: 0.7814837	total: 1.35s	remaining: 49.2s
# 20:	learn: 0.7769662	total: 1.41s	remaining: 49s
# 21:	learn: 0.7726664	total: 1.49s	remaining: 49.3s
# 22:	learn: 0.7677445	total: 1.58s	remaining: 50s
# 23:	learn: 0.7637472	total: 1.68s	remaining: 50.8s
# 24:	learn: 0.7592599	total: 1.75s	remaining: 50.8s
# 25:	learn: 0.7559246	total: 1.82s	remaining: 50.7s
# 26:	learn: 0.7526399	total: 1.89s	remaining: 50.6s
# 27:	learn: 0.7496864	total: 1.95s	remaining: 50.3s
# 28:	learn: 0.7473076	total: 2.02s	remaining: 50.1s
# 29:	learn: 0.7443082	total: 2.12s	remaining: 50.9s
# 30:	learn: 0.7416842	total: 2.19s	remaining: 50.9s
# 31:	learn: 0.7393354	total: 2.27s	remaining: 50.9s
# 32:	learn: 0.7367725	total: 2.33s	remaining: 50.7s
# 33:	learn: 0.7346212	total: 2.41s	remaining: 50.7s
# 34:	learn: 0.7314720	total: 2.48s	remaining: 50.7s
# 35:	learn: 0.7294088	total: 2.55s	remaining: 50.5s
# 36:	learn: 0.7265177	total: 2.61s	remaining: 50.3s
# 37:	learn: 0.7247510	total: 2.68s	remaining: 50.3s
# 38:	learn: 0.7231212	total: 2.75s	remaining: 50.2s
# 39:	learn: 0.7202299	total: 2.82s	remaining: 50.1s
# 40:	learn: 0.7186222	total: 2.89s	remaining: 50s
# 41:	learn: 0.7168914	total: 2.96s	remaining: 50s
# 42:	learn: 0.7150938	total: 3.03s	remaining: 49.9s
# 43:	learn: 0.7130970	total: 3.15s	remaining: 50.5s
# 44:	learn: 0.7116289	total: 3.23s	remaining: 50.6s
# 45:	learn: 0.7096952	total: 3.3s	remaining: 50.5s
# 46:	learn: 0.7078815	total: 3.38s	remaining: 50.5s
# 47:	learn: 0.7067670	total: 3.45s	remaining: 50.5s
# 48:	learn: 0.7048334	total: 3.52s	remaining: 50.4s
# 49:	learn: 0.7032211	total: 3.61s	remaining: 50.5s
# 50:	learn: 0.7021611	total: 3.68s	remaining: 50.4s
# 51:	learn: 0.7001919	total: 3.74s	remaining: 50.2s
# 52:	learn: 0.6985390	total: 3.8s	remaining: 50s
# 53:	learn: 0.6971884	total: 3.88s	remaining: 50s
# 54:	learn: 0.6953941	total: 3.96s	remaining: 50s
# 55:	learn: 0.6945380	total: 4.03s	remaining: 50s
# 56:	learn: 0.6931226	total: 4.1s	remaining: 49.8s
# 57:	learn: 0.6917412	total: 4.16s	remaining: 49.7s
# 58:	learn: 0.6901441	total: 4.23s	remaining: 49.5s
# 59:	learn: 0.6893801	total: 4.3s	remaining: 49.5s
# 60:	learn: 0.6882483	total: 4.38s	remaining: 49.5s
# 61:	learn: 0.6870313	total: 4.46s	remaining: 49.5s
# 62:	learn: 0.6856646	total: 4.53s	remaining: 49.4s
# 63:	learn: 0.6848208	total: 4.61s	remaining: 49.4s
# 64:	learn: 0.6833253	total: 4.67s	remaining: 49.2s
# 65:	learn: 0.6824346	total: 4.73s	remaining: 49s
# 66:	learn: 0.6810981	total: 4.79s	remaining: 48.9s
# 67:	learn: 0.6800341	total: 4.87s	remaining: 48.8s
# 68:	learn: 0.6789988	total: 4.93s	remaining: 48.7s
# 69:	learn: 0.6781998	total: 4.99s	remaining: 48.5s
# 70:	learn: 0.6767493	total: 5.06s	remaining: 48.4s
# 71:	learn: 0.6756672	total: 5.13s	remaining: 48.3s
# 72:	learn: 0.6746284	total: 5.2s	remaining: 48.2s
# 73:	learn: 0.6735757	total: 5.26s	remaining: 48s
# 74:	learn: 0.6728352	total: 5.32s	remaining: 47.9s
# 75:	learn: 0.6718705	total: 5.4s	remaining: 47.9s
# 76:	learn: 0.6706502	total: 5.45s	remaining: 47.7s
# 77:	learn: 0.6700035	total: 5.52s	remaining: 47.5s
# 78:	learn: 0.6694906	total: 5.58s	remaining: 47.4s
# 79:	learn: 0.6687698	total: 5.65s	remaining: 47.3s
# 80:	learn: 0.6678227	total: 5.71s	remaining: 47.1s
# 81:	learn: 0.6665323	total: 5.77s	remaining: 47s
# 82:	learn: 0.6650710	total: 5.84s	remaining: 46.9s
# 83:	learn: 0.6641629	total: 5.91s	remaining: 46.8s
# 84:	learn: 0.6633126	total: 5.98s	remaining: 46.8s
# 85:	learn: 0.6624329	total: 6.05s	remaining: 46.7s
# 86:	learn: 0.6619462	total: 6.12s	remaining: 46.6s
# 87:	learn: 0.6609067	total: 6.19s	remaining: 46.5s
# 88:	learn: 0.6598265	total: 6.24s	remaining: 46.4s
# 89:	learn: 0.6590317	total: 6.31s	remaining: 46.3s
# 90:	learn: 0.6581802	total: 6.39s	remaining: 46.3s
# 91:	learn: 0.6571088	total: 6.45s	remaining: 46.1s
# 92:	learn: 0.6561989	total: 6.51s	remaining: 46s
# 93:	learn: 0.6554500	total: 6.58s	remaining: 45.9s
# 94:	learn: 0.6541103	total: 6.65s	remaining: 45.8s
# 95:	learn: 0.6536030	total: 6.71s	remaining: 45.7s
# 96:	learn: 0.6523987	total: 6.79s	remaining: 45.7s
# 97:	learn: 0.6517516	total: 6.85s	remaining: 45.6s
# 98:	learn: 0.6507127	total: 6.93s	remaining: 45.6s
# 99:	learn: 0.6499254	total: 7.01s	remaining: 45.5s
# 100:	learn: 0.6486815	total: 7.08s	remaining: 45.5s
# 101:	learn: 0.6479815	total: 7.14s	remaining: 45.4s
# 102:	learn: 0.6469009	total: 7.21s	remaining: 45.3s
# 103:	learn: 0.6460764	total: 7.28s	remaining: 45.2s
# 104:	learn: 0.6448110	total: 7.34s	remaining: 45.1s
# 105:	learn: 0.6440167	total: 7.41s	remaining: 45s
# 106:	learn: 0.6430832	total: 7.47s	remaining: 44.9s
# 107:	learn: 0.6421921	total: 7.54s	remaining: 44.8s
# 108:	learn: 0.6411421	total: 7.6s	remaining: 44.7s
# 109:	learn: 0.6400800	total: 7.67s	remaining: 44.6s
# 110:	learn: 0.6395095	total: 7.73s	remaining: 44.5s
# 111:	learn: 0.6387163	total: 7.8s	remaining: 44.4s
# 112:	learn: 0.6375639	total: 7.9s	remaining: 44.5s
# 113:	learn: 0.6358432	total: 7.98s	remaining: 44.5s
# 114:	learn: 0.6349084	total: 8.05s	remaining: 44.5s
# 115:	learn: 0.6338630	total: 8.13s	remaining: 44.5s
# 116:	learn: 0.6328523	total: 8.2s	remaining: 44.4s
# 117:	learn: 0.6320990	total: 8.26s	remaining: 44.3s
# 118:	learn: 0.6314743	total: 8.32s	remaining: 44.1s
# 119:	learn: 0.6304318	total: 8.39s	remaining: 44.1s
# 120:	learn: 0.6287660	total: 8.46s	remaining: 44s
# 121:	learn: 0.6279386	total: 8.53s	remaining: 43.9s
# 122:	learn: 0.6270008	total: 8.59s	remaining: 43.8s
# 123:	learn: 0.6257713	total: 8.66s	remaining: 43.7s
# 124:	learn: 0.6247024	total: 8.73s	remaining: 43.6s
# 125:	learn: 0.6234295	total: 8.8s	remaining: 43.6s
# 126:	learn: 0.6223735	total: 8.87s	remaining: 43.5s
# 127:	learn: 0.6217297	total: 8.94s	remaining: 43.5s
# 128:	learn: 0.6202778	total: 9.01s	remaining: 43.4s
# 129:	learn: 0.6191980	total: 9.08s	remaining: 43.3s
# 130:	learn: 0.6182425	total: 9.16s	remaining: 43.3s
# 131:	learn: 0.6171853	total: 9.23s	remaining: 43.2s
# 132:	learn: 0.6158514	total: 9.3s	remaining: 43.2s
# 133:	learn: 0.6143857	total: 9.39s	remaining: 43.1s
# 134:	learn: 0.6133090	total: 9.45s	remaining: 43s
# 135:	learn: 0.6120115	total: 9.51s	remaining: 42.9s
# 136:	learn: 0.6112134	total: 9.57s	remaining: 42.8s
# 137:	learn: 0.6104691	total: 9.64s	remaining: 42.8s
# 138:	learn: 0.6094534	total: 9.7s	remaining: 42.7s
# 139:	learn: 0.6086174	total: 9.76s	remaining: 42.5s
# 140:	learn: 0.6076516	total: 9.82s	remaining: 42.4s
# 141:	learn: 0.6066930	total: 9.89s	remaining: 42.4s
# 142:	learn: 0.6055567	total: 9.96s	remaining: 42.3s
# 143:	learn: 0.6043866	total: 10s	remaining: 42.2s
# 144:	learn: 0.6030239	total: 10.1s	remaining: 42.1s
# 145:	learn: 0.6015546	total: 10.2s	remaining: 42s
# 146:	learn: 0.6001435	total: 10.2s	remaining: 42s
# 147:	learn: 0.5995737	total: 10.3s	remaining: 41.8s
# 148:	learn: 0.5986332	total: 10.4s	remaining: 41.8s
# 149:	learn: 0.5978760	total: 10.4s	remaining: 41.7s
# 150:	learn: 0.5966246	total: 10.5s	remaining: 41.6s
# 151:	learn: 0.5957549	total: 10.6s	remaining: 41.5s
# 152:	learn: 0.5946053	total: 10.6s	remaining: 41.5s
# 153:	learn: 0.5935185	total: 10.7s	remaining: 41.4s
# 154:	learn: 0.5925139	total: 10.8s	remaining: 41.3s
# 155:	learn: 0.5915518	total: 10.8s	remaining: 41.3s
# 156:	learn: 0.5904131	total: 10.9s	remaining: 41.3s
# 157:	learn: 0.5896325	total: 11s	remaining: 41.2s
# 158:	learn: 0.5885647	total: 11.1s	remaining: 41.1s
# 159:	learn: 0.5880457	total: 11.1s	remaining: 41s
# 160:	learn: 0.5869239	total: 11.2s	remaining: 41s
# 161:	learn: 0.5860512	total: 11.3s	remaining: 40.9s
# 162:	learn: 0.5851245	total: 11.3s	remaining: 40.8s
# 163:	learn: 0.5843950	total: 11.4s	remaining: 40.7s
# 164:	learn: 0.5840080	total: 11.5s	remaining: 40.6s
# 165:	learn: 0.5830680	total: 11.5s	remaining: 40.5s
# 166:	learn: 0.5817976	total: 11.6s	remaining: 40.5s
# 167:	learn: 0.5806624	total: 11.6s	remaining: 40.4s
# 168:	learn: 0.5797861	total: 11.7s	remaining: 40.3s
# 169:	learn: 0.5783547	total: 11.8s	remaining: 40.2s
# 170:	learn: 0.5778123	total: 11.8s	remaining: 40.1s
# 171:	learn: 0.5769373	total: 11.9s	remaining: 40s
# 172:	learn: 0.5757468	total: 12s	remaining: 40s
# 173:	learn: 0.5750215	total: 12.1s	remaining: 39.9s
# 174:	learn: 0.5743229	total: 12.1s	remaining: 39.8s
# 175:	learn: 0.5740878	total: 12.2s	remaining: 39.7s
# 176:	learn: 0.5729731	total: 12.2s	remaining: 39.6s
# 177:	learn: 0.5716974	total: 12.3s	remaining: 39.6s
# 178:	learn: 0.5714596	total: 12.4s	remaining: 39.5s
# 179:	learn: 0.5704470	total: 12.4s	remaining: 39.4s
# 180:	learn: 0.5695190	total: 12.5s	remaining: 39.3s
# 181:	learn: 0.5683514	total: 12.6s	remaining: 39.2s
# 182:	learn: 0.5670016	total: 12.6s	remaining: 39.1s
# 183:	learn: 0.5660641	total: 12.7s	remaining: 39s
# 184:	learn: 0.5659309	total: 12.8s	remaining: 39s
# 185:	learn: 0.5649013	total: 12.8s	remaining: 38.9s
# 186:	learn: 0.5641944	total: 12.9s	remaining: 38.8s
# 187:	learn: 0.5634418	total: 12.9s	remaining: 38.7s
# 188:	learn: 0.5625736	total: 13s	remaining: 38.6s
# 189:	learn: 0.5617425	total: 13.1s	remaining: 38.5s
# 190:	learn: 0.5607871	total: 13.1s	remaining: 38.5s
# 191:	learn: 0.5599500	total: 13.2s	remaining: 38.3s
# 192:	learn: 0.5591744	total: 13.3s	remaining: 38.3s
# 193:	learn: 0.5582474	total: 13.3s	remaining: 38.3s
# 194:	learn: 0.5572751	total: 13.4s	remaining: 38.2s
# 195:	learn: 0.5560206	total: 13.5s	remaining: 38.1s
# 196:	learn: 0.5554600	total: 13.5s	remaining: 38s
# 197:	learn: 0.5548728	total: 13.6s	remaining: 37.9s
# 198:	learn: 0.5540963	total: 13.7s	remaining: 37.8s
# 199:	learn: 0.5533053	total: 13.7s	remaining: 37.8s
# 200:	learn: 0.5530529	total: 13.8s	remaining: 37.7s
# 201:	learn: 0.5521298	total: 13.9s	remaining: 37.6s
# 202:	learn: 0.5514610	total: 13.9s	remaining: 37.5s
# 203:	learn: 0.5504873	total: 14s	remaining: 37.5s
# 204:	learn: 0.5497374	total: 14.1s	remaining: 37.4s
# 205:	learn: 0.5489496	total: 14.1s	remaining: 37.3s
# 206:	learn: 0.5482839	total: 14.2s	remaining: 37.3s
# 207:	learn: 0.5475617	total: 14.3s	remaining: 37.2s
# 208:	learn: 0.5467899	total: 14.3s	remaining: 37.1s
# 209:	learn: 0.5458509	total: 14.4s	remaining: 37.1s
# 210:	learn: 0.5449118	total: 14.5s	remaining: 37.1s
# 211:	learn: 0.5443212	total: 14.6s	remaining: 37s
# 212:	learn: 0.5432556	total: 14.7s	remaining: 37s
# 213:	learn: 0.5423928	total: 14.7s	remaining: 36.9s
# 214:	learn: 0.5415867	total: 14.8s	remaining: 36.9s
# 215:	learn: 0.5410284	total: 14.9s	remaining: 36.8s
# 216:	learn: 0.5405668	total: 15s	remaining: 36.8s
# 217:	learn: 0.5397991	total: 15.1s	remaining: 36.7s
# 218:	learn: 0.5396714	total: 15.1s	remaining: 36.7s
# 219:	learn: 0.5388703	total: 15.2s	remaining: 36.6s
# 220:	learn: 0.5380528	total: 15.3s	remaining: 36.6s
# 221:	learn: 0.5377045	total: 15.3s	remaining: 36.5s
# 222:	learn: 0.5370100	total: 15.4s	remaining: 36.4s
# 223:	learn: 0.5358754	total: 15.5s	remaining: 36.4s
# 224:	learn: 0.5349810	total: 15.6s	remaining: 36.4s
# 225:	learn: 0.5341223	total: 15.7s	remaining: 36.3s
# 226:	learn: 0.5335746	total: 15.8s	remaining: 36.3s
# 227:	learn: 0.5324657	total: 15.8s	remaining: 36.3s
# 228:	learn: 0.5317137	total: 15.9s	remaining: 36.2s
# 229:	learn: 0.5311892	total: 16s	remaining: 36.1s
# 230:	learn: 0.5304337	total: 16s	remaining: 36s
# 231:	learn: 0.5298330	total: 16.1s	remaining: 36s
# 232:	learn: 0.5290035	total: 16.2s	remaining: 35.9s
# 233:	learn: 0.5283436	total: 16.3s	remaining: 35.9s
# 234:	learn: 0.5275961	total: 16.3s	remaining: 35.8s
# 235:	learn: 0.5265118	total: 16.4s	remaining: 35.7s
# 236:	learn: 0.5261953	total: 16.5s	remaining: 35.6s
# 237:	learn: 0.5252906	total: 16.5s	remaining: 35.5s
# 238:	learn: 0.5247052	total: 16.6s	remaining: 35.5s
# 239:	learn: 0.5236971	total: 16.7s	remaining: 35.4s
# 240:	learn: 0.5225912	total: 16.7s	remaining: 35.3s
# 241:	learn: 0.5221347	total: 16.8s	remaining: 35.3s
# 242:	learn: 0.5216557	total: 16.9s	remaining: 35.2s
# 243:	learn: 0.5207699	total: 16.9s	remaining: 35.1s
# 244:	learn: 0.5200437	total: 17s	remaining: 35.1s
# 245:	learn: 0.5191145	total: 17.1s	remaining: 35.1s
# 246:	learn: 0.5182738	total: 17.2s	remaining: 35s
# 247:	learn: 0.5174712	total: 17.3s	remaining: 35s
# 248:	learn: 0.5169092	total: 17.3s	remaining: 34.9s
# 249:	learn: 0.5163725	total: 17.4s	remaining: 34.8s
# 250:	learn: 0.5158350	total: 17.5s	remaining: 34.8s
# 251:	learn: 0.5152458	total: 17.6s	remaining: 34.7s
# 252:	learn: 0.5143340	total: 17.6s	remaining: 34.6s
# 253:	learn: 0.5136821	total: 17.7s	remaining: 34.6s
# 254:	learn: 0.5128827	total: 17.8s	remaining: 34.5s
# 255:	learn: 0.5123992	total: 17.8s	remaining: 34.4s
# 256:	learn: 0.5115169	total: 17.9s	remaining: 34.3s
# 257:	learn: 0.5106221	total: 18s	remaining: 34.3s
# 258:	learn: 0.5101678	total: 18s	remaining: 34.2s
# 259:	learn: 0.5096571	total: 18.1s	remaining: 34.1s
# 260:	learn: 0.5090224	total: 18.2s	remaining: 34.1s
# 261:	learn: 0.5084568	total: 18.3s	remaining: 34s
# 262:	learn: 0.5077526	total: 18.3s	remaining: 33.9s
# 263:	learn: 0.5069582	total: 18.4s	remaining: 33.8s
# 264:	learn: 0.5060470	total: 18.5s	remaining: 33.8s
# 265:	learn: 0.5053313	total: 18.5s	remaining: 33.7s
# 266:	learn: 0.5046032	total: 18.6s	remaining: 33.6s
# 267:	learn: 0.5037576	total: 18.7s	remaining: 33.6s
# 268:	learn: 0.5031904	total: 18.8s	remaining: 33.5s
# 269:	learn: 0.5027844	total: 18.8s	remaining: 33.5s
# 270:	learn: 0.5026818	total: 18.9s	remaining: 33.4s
# 271:	learn: 0.5017679	total: 19s	remaining: 33.3s
# 272:	learn: 0.5010314	total: 19s	remaining: 33.3s
# 273:	learn: 0.5001919	total: 19.1s	remaining: 33.2s
# 274:	learn: 0.4995231	total: 19.2s	remaining: 33.1s
# 275:	learn: 0.4989776	total: 19.2s	remaining: 33s
# 276:	learn: 0.4981610	total: 19.3s	remaining: 33s
# 277:	learn: 0.4977074	total: 19.4s	remaining: 32.9s
# 278:	learn: 0.4970385	total: 19.4s	remaining: 32.8s
# 279:	learn: 0.4962548	total: 19.5s	remaining: 32.7s
# 280:	learn: 0.4961469	total: 19.6s	remaining: 32.6s
# 281:	learn: 0.4952873	total: 19.6s	remaining: 32.6s
# 282:	learn: 0.4950869	total: 19.7s	remaining: 32.5s
# 283:	learn: 0.4946012	total: 19.7s	remaining: 32.4s
# 284:	learn: 0.4940157	total: 19.8s	remaining: 32.3s
# 285:	learn: 0.4934268	total: 19.9s	remaining: 32.2s
# 286:	learn: 0.4928017	total: 19.9s	remaining: 32.2s
# 287:	learn: 0.4923456	total: 20s	remaining: 32.1s
# 288:	learn: 0.4921165	total: 20.1s	remaining: 32s
# 289:	learn: 0.4914976	total: 20.1s	remaining: 32s
# 290:	learn: 0.4907678	total: 20.2s	remaining: 31.9s
# 291:	learn: 0.4904198	total: 20.3s	remaining: 31.8s
# 292:	learn: 0.4898800	total: 20.3s	remaining: 31.7s
# 293:	learn: 0.4892941	total: 20.4s	remaining: 31.6s
# 294:	learn: 0.4887124	total: 20.5s	remaining: 31.6s
# 295:	learn: 0.4881513	total: 20.5s	remaining: 31.5s
# 296:	learn: 0.4878743	total: 20.6s	remaining: 31.4s
# 297:	learn: 0.4873661	total: 20.7s	remaining: 31.4s
# 298:	learn: 0.4872251	total: 20.7s	remaining: 31.3s
# 299:	learn: 0.4868870	total: 20.8s	remaining: 31.2s
# 300:	learn: 0.4861583	total: 20.9s	remaining: 31.1s
# 301:	learn: 0.4854451	total: 20.9s	remaining: 31s
# 302:	learn: 0.4848022	total: 21s	remaining: 31s
# 303:	learn: 0.4842814	total: 21.1s	remaining: 30.9s
# 304:	learn: 0.4838779	total: 21.1s	remaining: 30.8s
# 305:	learn: 0.4837628	total: 21.2s	remaining: 30.7s
# 306:	learn: 0.4830325	total: 21.2s	remaining: 30.7s
# 307:	learn: 0.4822973	total: 21.3s	remaining: 30.6s
# 308:	learn: 0.4818447	total: 21.4s	remaining: 30.5s
# 309:	learn: 0.4812884	total: 21.4s	remaining: 30.4s
# 310:	learn: 0.4806791	total: 21.5s	remaining: 30.4s
# 311:	learn: 0.4799272	total: 21.6s	remaining: 30.3s
# 312:	learn: 0.4791234	total: 21.6s	remaining: 30.2s
# 313:	learn: 0.4786086	total: 21.7s	remaining: 30.1s
# 314:	learn: 0.4778837	total: 21.8s	remaining: 30.1s
# 315:	learn: 0.4772297	total: 21.8s	remaining: 30s
# 316:	learn: 0.4768980	total: 21.9s	remaining: 29.9s
# 317:	learn: 0.4763301	total: 22s	remaining: 29.8s
# 318:	learn: 0.4753697	total: 22s	remaining: 29.7s
# 319:	learn: 0.4748404	total: 22.1s	remaining: 29.7s
# 320:	learn: 0.4747657	total: 22.1s	remaining: 29.6s
# 321:	learn: 0.4740711	total: 22.2s	remaining: 29.5s
# 322:	learn: 0.4735720	total: 22.3s	remaining: 29.4s
# 323:	learn: 0.4730795	total: 22.3s	remaining: 29.4s
# 324:	learn: 0.4723418	total: 22.4s	remaining: 29.3s
# 325:	learn: 0.4714513	total: 22.4s	remaining: 29.2s
# 326:	learn: 0.4707754	total: 22.5s	remaining: 29.1s
# 327:	learn: 0.4702217	total: 22.6s	remaining: 29.1s
# 328:	learn: 0.4694777	total: 22.6s	remaining: 29s
# 329:	learn: 0.4687847	total: 22.7s	remaining: 28.9s
# 330:	learn: 0.4684392	total: 22.8s	remaining: 28.8s
# 331:	learn: 0.4677824	total: 22.8s	remaining: 28.8s
# 332:	learn: 0.4672782	total: 22.9s	remaining: 28.7s
# 333:	learn: 0.4664729	total: 23s	remaining: 28.6s
# 334:	learn: 0.4661223	total: 23s	remaining: 28.6s
# 335:	learn: 0.4655774	total: 23.1s	remaining: 28.5s
# 336:	learn: 0.4648380	total: 23.2s	remaining: 28.4s
# 337:	learn: 0.4641248	total: 23.2s	remaining: 28.3s
# 338:	learn: 0.4635395	total: 23.3s	remaining: 28.3s
# 339:	learn: 0.4629901	total: 23.4s	remaining: 28.2s
# 340:	learn: 0.4626461	total: 23.4s	remaining: 28.1s
# 341:	learn: 0.4617720	total: 23.5s	remaining: 28s
# 342:	learn: 0.4609995	total: 23.6s	remaining: 28s
# 343:	learn: 0.4603579	total: 23.6s	remaining: 27.9s
# 344:	learn: 0.4596676	total: 23.7s	remaining: 27.8s
# 345:	learn: 0.4590768	total: 23.8s	remaining: 27.8s
# 346:	learn: 0.4586304	total: 23.8s	remaining: 27.7s
# 347:	learn: 0.4578789	total: 23.9s	remaining: 27.6s
# 348:	learn: 0.4573752	total: 24s	remaining: 27.5s
# 349:	learn: 0.4565905	total: 24s	remaining: 27.5s
# 350:	learn: 0.4559598	total: 24.1s	remaining: 27.4s
# 351:	learn: 0.4554064	total: 24.2s	remaining: 27.3s
# 352:	learn: 0.4547631	total: 24.2s	remaining: 27.3s
# 353:	learn: 0.4541923	total: 24.3s	remaining: 27.2s
# 354:	learn: 0.4536238	total: 24.4s	remaining: 27.1s
# 355:	learn: 0.4530972	total: 24.4s	remaining: 27s
# 356:	learn: 0.4526394	total: 24.5s	remaining: 27s
# 357:	learn: 0.4518606	total: 24.6s	remaining: 26.9s
# 358:	learn: 0.4512822	total: 24.6s	remaining: 26.8s
# 359:	learn: 0.4510364	total: 24.7s	remaining: 26.8s
# 360:	learn: 0.4503179	total: 24.8s	remaining: 26.7s
# 361:	learn: 0.4497397	total: 24.8s	remaining: 26.6s
# 362:	learn: 0.4490089	total: 24.9s	remaining: 26.6s
# 363:	learn: 0.4484697	total: 25s	remaining: 26.5s
# 364:	learn: 0.4477278	total: 25s	remaining: 26.4s
# 365:	learn: 0.4471351	total: 25.1s	remaining: 26.3s
# 366:	learn: 0.4466652	total: 25.2s	remaining: 26.3s
# 367:	learn: 0.4461001	total: 25.3s	remaining: 26.2s
# 368:	learn: 0.4452550	total: 25.3s	remaining: 26.2s
# 369:	learn: 0.4450103	total: 25.4s	remaining: 26.1s
# 370:	learn: 0.4443747	total: 25.5s	remaining: 26s
# 371:	learn: 0.4438030	total: 25.5s	remaining: 25.9s
# 372:	learn: 0.4433369	total: 25.6s	remaining: 25.9s
# 373:	learn: 0.4428910	total: 25.7s	remaining: 25.8s
# 374:	learn: 0.4423439	total: 25.8s	remaining: 25.8s
# 375:	learn: 0.4419773	total: 25.8s	remaining: 25.7s
# 376:	learn: 0.4414420	total: 25.9s	remaining: 25.6s
# 377:	learn: 0.4407988	total: 26s	remaining: 25.6s
# 378:	learn: 0.4401213	total: 26.1s	remaining: 25.5s
# 379:	learn: 0.4393222	total: 26.1s	remaining: 25.4s
# 380:	learn: 0.4386780	total: 26.2s	remaining: 25.4s
# 381:	learn: 0.4383935	total: 26.3s	remaining: 25.3s
# 382:	learn: 0.4380588	total: 26.3s	remaining: 25.2s
# 383:	learn: 0.4371970	total: 26.4s	remaining: 25.2s
# 384:	learn: 0.4365496	total: 26.5s	remaining: 25.1s
# 385:	learn: 0.4358724	total: 26.6s	remaining: 25s
# 386:	learn: 0.4350822	total: 26.6s	remaining: 25s
# 387:	learn: 0.4347489	total: 26.7s	remaining: 24.9s
# 388:	learn: 0.4343191	total: 26.8s	remaining: 24.8s
# 389:	learn: 0.4337507	total: 26.8s	remaining: 24.8s
# 390:	learn: 0.4333070	total: 26.9s	remaining: 24.7s
# 391:	learn: 0.4324554	total: 27s	remaining: 24.6s
# 392:	learn: 0.4319801	total: 27.1s	remaining: 24.6s
# 393:	learn: 0.4314328	total: 27.1s	remaining: 24.5s
# 394:	learn: 0.4309267	total: 27.2s	remaining: 24.4s
# 395:	learn: 0.4308512	total: 27.3s	remaining: 24.4s
# 396:	learn: 0.4303428	total: 27.3s	remaining: 24.3s
# 397:	learn: 0.4297444	total: 27.4s	remaining: 24.2s
# 398:	learn: 0.4288360	total: 27.5s	remaining: 24.2s
# 399:	learn: 0.4281336	total: 27.5s	remaining: 24.1s
# 400:	learn: 0.4275830	total: 27.6s	remaining: 24s
# 401:	learn: 0.4271677	total: 27.7s	remaining: 24s
# 402:	learn: 0.4265191	total: 27.7s	remaining: 23.9s
# 403:	learn: 0.4259390	total: 27.8s	remaining: 23.8s
# 404:	learn: 0.4254238	total: 27.9s	remaining: 23.7s
# 405:	learn: 0.4248419	total: 27.9s	remaining: 23.7s
# 406:	learn: 0.4244080	total: 28s	remaining: 23.6s
# 407:	learn: 0.4241151	total: 28.1s	remaining: 23.5s
# 408:	learn: 0.4238440	total: 28.1s	remaining: 23.5s
# 409:	learn: 0.4233241	total: 28.2s	remaining: 23.4s
# 410:	learn: 0.4225204	total: 28.3s	remaining: 23.3s
# 411:	learn: 0.4219421	total: 28.4s	remaining: 23.3s
# 412:	learn: 0.4215567	total: 28.4s	remaining: 23.2s
# 413:	learn: 0.4210625	total: 28.5s	remaining: 23.1s
# 414:	learn: 0.4206523	total: 28.6s	remaining: 23.1s
# 415:	learn: 0.4199372	total: 28.6s	remaining: 23s
# 416:	learn: 0.4194642	total: 28.7s	remaining: 22.9s
# 417:	learn: 0.4189919	total: 28.8s	remaining: 22.9s
# 418:	learn: 0.4182504	total: 28.9s	remaining: 22.8s
# 419:	learn: 0.4177556	total: 28.9s	remaining: 22.7s
# 420:	learn: 0.4172475	total: 29s	remaining: 22.7s
# 421:	learn: 0.4170630	total: 29.1s	remaining: 22.6s
# 422:	learn: 0.4165322	total: 29.2s	remaining: 22.5s
# 423:	learn: 0.4159326	total: 29.2s	remaining: 22.5s
# 424:	learn: 0.4152893	total: 29.3s	remaining: 22.4s
# 425:	learn: 0.4147752	total: 29.4s	remaining: 22.4s
# 426:	learn: 0.4143452	total: 29.4s	remaining: 22.3s
# 427:	learn: 0.4139629	total: 29.5s	remaining: 22.2s
# 428:	learn: 0.4133881	total: 29.6s	remaining: 22.1s
# 429:	learn: 0.4129670	total: 29.6s	remaining: 22.1s
# 430:	learn: 0.4123371	total: 29.7s	remaining: 22s
# 431:	learn: 0.4119271	total: 29.8s	remaining: 21.9s
# 432:	learn: 0.4113601	total: 29.8s	remaining: 21.8s
# 433:	learn: 0.4110269	total: 29.9s	remaining: 21.8s
# 434:	learn: 0.4105880	total: 30s	remaining: 21.7s
# 435:	learn: 0.4100098	total: 30s	remaining: 21.6s
# 436:	learn: 0.4094589	total: 30.1s	remaining: 21.6s
# 437:	learn: 0.4087012	total: 30.2s	remaining: 21.5s
# 438:	learn: 0.4081739	total: 30.2s	remaining: 21.4s
# 439:	learn: 0.4077002	total: 30.3s	remaining: 21.4s
# 440:	learn: 0.4073554	total: 30.4s	remaining: 21.3s
# 441:	learn: 0.4068290	total: 30.4s	remaining: 21.2s
# 442:	learn: 0.4060746	total: 30.5s	remaining: 21.1s
# 443:	learn: 0.4056579	total: 30.5s	remaining: 21.1s
# 444:	learn: 0.4050436	total: 30.6s	remaining: 21s
# 445:	learn: 0.4044883	total: 30.7s	remaining: 20.9s
# 446:	learn: 0.4040303	total: 30.7s	remaining: 20.8s
# 447:	learn: 0.4031295	total: 30.8s	remaining: 20.8s
# 448:	learn: 0.4025222	total: 30.9s	remaining: 20.7s
# 449:	learn: 0.4018527	total: 30.9s	remaining: 20.6s
# 450:	learn: 0.4014441	total: 31s	remaining: 20.6s
# 451:	learn: 0.4013866	total: 31.1s	remaining: 20.5s
# 452:	learn: 0.4007905	total: 31.1s	remaining: 20.4s
# 453:	learn: 0.3999140	total: 31.2s	remaining: 20.3s
# 454:	learn: 0.3992270	total: 31.3s	remaining: 20.3s
# 455:	learn: 0.3986349	total: 31.3s	remaining: 20.2s
# 456:	learn: 0.3979581	total: 31.4s	remaining: 20.1s
# 457:	learn: 0.3973687	total: 31.5s	remaining: 20.1s
# 458:	learn: 0.3970607	total: 31.5s	remaining: 20s
# 459:	learn: 0.3967880	total: 31.6s	remaining: 19.9s
# 460:	learn: 0.3962144	total: 31.7s	remaining: 19.9s
# 461:	learn: 0.3957018	total: 31.7s	remaining: 19.8s
# 462:	learn: 0.3950949	total: 31.8s	remaining: 19.7s
# 463:	learn: 0.3944206	total: 31.9s	remaining: 19.6s
# 464:	learn: 0.3937746	total: 31.9s	remaining: 19.6s
# 465:	learn: 0.3934203	total: 32s	remaining: 19.5s
# 466:	learn: 0.3926163	total: 32.1s	remaining: 19.4s
# 467:	learn: 0.3919081	total: 32.1s	remaining: 19.4s
# 468:	learn: 0.3911423	total: 32.2s	remaining: 19.3s
# 469:	learn: 0.3906846	total: 32.3s	remaining: 19.2s
# 470:	learn: 0.3902637	total: 32.3s	remaining: 19.2s
# 471:	learn: 0.3899248	total: 32.4s	remaining: 19.1s
# 472:	learn: 0.3890891	total: 32.5s	remaining: 19s
# 473:	learn: 0.3885563	total: 32.5s	remaining: 18.9s
# 474:	learn: 0.3882179	total: 32.6s	remaining: 18.9s
# 475:	learn: 0.3877062	total: 32.6s	remaining: 18.8s
# 476:	learn: 0.3870297	total: 32.7s	remaining: 18.7s
# 477:	learn: 0.3866269	total: 32.8s	remaining: 18.7s
# 478:	learn: 0.3861538	total: 32.8s	remaining: 18.6s
# 479:	learn: 0.3857194	total: 32.9s	remaining: 18.5s
# 480:	learn: 0.3854767	total: 33s	remaining: 18.4s
# 481:	learn: 0.3851538	total: 33s	remaining: 18.4s
# 482:	learn: 0.3847362	total: 33.1s	remaining: 18.3s
# 483:	learn: 0.3842742	total: 33.2s	remaining: 18.2s
# 484:	learn: 0.3839080	total: 33.2s	remaining: 18.2s
# 485:	learn: 0.3838721	total: 33.3s	remaining: 18.1s
# 486:	learn: 0.3836522	total: 33.3s	remaining: 18s
# 487:	learn: 0.3832831	total: 33.4s	remaining: 17.9s
# 488:	learn: 0.3827801	total: 33.5s	remaining: 17.9s
# 489:	learn: 0.3825362	total: 33.5s	remaining: 17.8s
# 490:	learn: 0.3819752	total: 33.6s	remaining: 17.7s
# 491:	learn: 0.3815722	total: 33.7s	remaining: 17.7s
# 492:	learn: 0.3811530	total: 33.8s	remaining: 17.6s
# 493:	learn: 0.3807989	total: 33.8s	remaining: 17.5s
# 494:	learn: 0.3801999	total: 33.9s	remaining: 17.5s
# 495:	learn: 0.3798610	total: 34s	remaining: 17.4s
# 496:	learn: 0.3795342	total: 34s	remaining: 17.3s
# 497:	learn: 0.3790641	total: 34.1s	remaining: 17.3s
# 498:	learn: 0.3785091	total: 34.2s	remaining: 17.2s
# 499:	learn: 0.3778870	total: 34.2s	remaining: 17.1s
# 500:	learn: 0.3772774	total: 34.3s	remaining: 17.1s
# 501:	learn: 0.3766518	total: 34.4s	remaining: 17s
# 502:	learn: 0.3760826	total: 34.4s	remaining: 16.9s
# 503:	learn: 0.3756131	total: 34.5s	remaining: 16.8s
# 504:	learn: 0.3752397	total: 34.6s	remaining: 16.8s
# 505:	learn: 0.3747364	total: 34.6s	remaining: 16.7s
# 506:	learn: 0.3742856	total: 34.7s	remaining: 16.6s
# 507:	learn: 0.3736248	total: 34.8s	remaining: 16.6s
# 508:	learn: 0.3733750	total: 34.8s	remaining: 16.5s
# 509:	learn: 0.3731026	total: 34.9s	remaining: 16.4s
# 510:	learn: 0.3727351	total: 35s	remaining: 16.4s
# 511:	learn: 0.3722898	total: 35s	remaining: 16.3s
# 512:	learn: 0.3719933	total: 35.1s	remaining: 16.2s
# 513:	learn: 0.3714091	total: 35.2s	remaining: 16.1s
# 514:	learn: 0.3710111	total: 35.2s	remaining: 16.1s
# 515:	learn: 0.3706715	total: 35.3s	remaining: 16s
# 516:	learn: 0.3701594	total: 35.4s	remaining: 15.9s
# 517:	learn: 0.3695178	total: 35.4s	remaining: 15.9s
# 518:	learn: 0.3690422	total: 35.5s	remaining: 15.8s
# 519:	learn: 0.3685159	total: 35.6s	remaining: 15.7s
# 520:	learn: 0.3680515	total: 35.7s	remaining: 15.7s
# 521:	learn: 0.3675989	total: 35.7s	remaining: 15.6s
# 522:	learn: 0.3670382	total: 35.8s	remaining: 15.5s
# 523:	learn: 0.3666505	total: 35.9s	remaining: 15.5s
# 524:	learn: 0.3661863	total: 35.9s	remaining: 15.4s
# 525:	learn: 0.3655804	total: 36s	remaining: 15.3s
# 526:	learn: 0.3651109	total: 36.1s	remaining: 15.3s
# 527:	learn: 0.3646514	total: 36.2s	remaining: 15.2s
# 528:	learn: 0.3641866	total: 36.2s	remaining: 15.1s
# 529:	learn: 0.3638316	total: 36.3s	remaining: 15.1s
# 530:	learn: 0.3633508	total: 36.4s	remaining: 15s
# 531:	learn: 0.3629414	total: 36.5s	remaining: 14.9s
# 532:	learn: 0.3624105	total: 36.5s	remaining: 14.9s
# 533:	learn: 0.3616950	total: 36.6s	remaining: 14.8s
# 534:	learn: 0.3611790	total: 36.7s	remaining: 14.7s
# 535:	learn: 0.3607270	total: 36.7s	remaining: 14.7s
# 536:	learn: 0.3604489	total: 36.8s	remaining: 14.6s
# 537:	learn: 0.3599075	total: 36.8s	remaining: 14.5s
# 538:	learn: 0.3594875	total: 36.9s	remaining: 14.4s
# 539:	learn: 0.3590260	total: 37s	remaining: 14.4s
# 540:	learn: 0.3583942	total: 37s	remaining: 14.3s
# 541:	learn: 0.3578924	total: 37.1s	remaining: 14.2s
# 542:	learn: 0.3575246	total: 37.2s	remaining: 14.2s
# 543:	learn: 0.3569062	total: 37.3s	remaining: 14.1s
# 544:	learn: 0.3564812	total: 37.3s	remaining: 14s
# 545:	learn: 0.3561327	total: 37.4s	remaining: 14s
# 546:	learn: 0.3555633	total: 37.5s	remaining: 13.9s
# 547:	learn: 0.3552028	total: 37.6s	remaining: 13.8s
# 548:	learn: 0.3548941	total: 37.6s	remaining: 13.8s
# 549:	learn: 0.3545424	total: 37.7s	remaining: 13.7s
# 550:	learn: 0.3541202	total: 37.8s	remaining: 13.6s
# 551:	learn: 0.3536431	total: 37.8s	remaining: 13.6s
# 552:	learn: 0.3531767	total: 37.9s	remaining: 13.5s
# 553:	learn: 0.3527832	total: 38s	remaining: 13.4s
# 554:	learn: 0.3522358	total: 38s	remaining: 13.4s
# 555:	learn: 0.3519600	total: 38.1s	remaining: 13.3s
# 556:	learn: 0.3515326	total: 38.2s	remaining: 13.2s
# 557:	learn: 0.3511804	total: 38.2s	remaining: 13.2s
# 558:	learn: 0.3507561	total: 38.3s	remaining: 13.1s
# 559:	learn: 0.3504335	total: 38.4s	remaining: 13s
# 560:	learn: 0.3500600	total: 38.4s	remaining: 12.9s
# 561:	learn: 0.3497257	total: 38.5s	remaining: 12.9s
# 562:	learn: 0.3492769	total: 38.6s	remaining: 12.8s
# 563:	learn: 0.3487211	total: 38.6s	remaining: 12.7s
# 564:	learn: 0.3482535	total: 38.7s	remaining: 12.7s
# 565:	learn: 0.3478457	total: 38.8s	remaining: 12.6s
# 566:	learn: 0.3478016	total: 38.8s	remaining: 12.5s
# 567:	learn: 0.3472232	total: 38.9s	remaining: 12.5s
# 568:	learn: 0.3466881	total: 39s	remaining: 12.4s
# 569:	learn: 0.3462889	total: 39.1s	remaining: 12.3s
# 570:	learn: 0.3458271	total: 39.2s	remaining: 12.3s
# 571:	learn: 0.3453771	total: 39.2s	remaining: 12.2s
# 572:	learn: 0.3448898	total: 39.3s	remaining: 12.1s
# 573:	learn: 0.3444432	total: 39.4s	remaining: 12.1s
# 574:	learn: 0.3438642	total: 39.5s	remaining: 12s
# 575:	learn: 0.3434086	total: 39.5s	remaining: 11.9s
# 576:	learn: 0.3432035	total: 39.6s	remaining: 11.9s
# 577:	learn: 0.3427493	total: 39.7s	remaining: 11.8s
# 578:	learn: 0.3421950	total: 39.7s	remaining: 11.7s
# 579:	learn: 0.3416514	total: 39.8s	remaining: 11.7s
# 580:	learn: 0.3412238	total: 39.9s	remaining: 11.6s
# 581:	learn: 0.3410928	total: 40s	remaining: 11.5s
# 582:	learn: 0.3407369	total: 40.1s	remaining: 11.5s
# 583:	learn: 0.3403996	total: 40.1s	remaining: 11.4s
# 584:	learn: 0.3400341	total: 40.2s	remaining: 11.3s
# 585:	learn: 0.3395265	total: 40.3s	remaining: 11.3s
# 586:	learn: 0.3392101	total: 40.3s	remaining: 11.2s
# 587:	learn: 0.3388758	total: 40.4s	remaining: 11.1s
# 588:	learn: 0.3383905	total: 40.5s	remaining: 11.1s
# 589:	learn: 0.3380518	total: 40.6s	remaining: 11s
# 590:	learn: 0.3375671	total: 40.6s	remaining: 10.9s
# 591:	learn: 0.3369778	total: 40.7s	remaining: 10.9s
# 592:	learn: 0.3367170	total: 40.8s	remaining: 10.8s
# 593:	learn: 0.3362662	total: 40.8s	remaining: 10.7s
# 594:	learn: 0.3360462	total: 40.9s	remaining: 10.7s
# 595:	learn: 0.3355438	total: 41s	remaining: 10.6s
# 596:	learn: 0.3350933	total: 41.1s	remaining: 10.5s
# 597:	learn: 0.3346842	total: 41.1s	remaining: 10.5s
# 598:	learn: 0.3342378	total: 41.2s	remaining: 10.4s
# 599:	learn: 0.3338207	total: 41.3s	remaining: 10.3s
# 600:	learn: 0.3333127	total: 41.3s	remaining: 10.2s
# 601:	learn: 0.3330020	total: 41.4s	remaining: 10.2s
# 602:	learn: 0.3326309	total: 41.4s	remaining: 10.1s
# 603:	learn: 0.3322218	total: 41.5s	remaining: 10s
# 604:	learn: 0.3321821	total: 41.6s	remaining: 9.96s
# 605:	learn: 0.3318159	total: 41.6s	remaining: 9.89s
# 606:	learn: 0.3315205	total: 41.7s	remaining: 9.83s
# 607:	learn: 0.3311157	total: 41.8s	remaining: 9.76s
# 608:	learn: 0.3308981	total: 41.9s	remaining: 9.69s
# 609:	learn: 0.3305233	total: 41.9s	remaining: 9.63s
# 610:	learn: 0.3301718	total: 42s	remaining: 9.56s
# 611:	learn: 0.3298647	total: 42.1s	remaining: 9.48s
# 612:	learn: 0.3294967	total: 42.1s	remaining: 9.41s
# 613:	learn: 0.3292886	total: 42.2s	remaining: 9.35s
# 614:	learn: 0.3286432	total: 42.3s	remaining: 9.28s
# 615:	learn: 0.3282387	total: 42.4s	remaining: 9.21s
# 616:	learn: 0.3279437	total: 42.4s	remaining: 9.14s
# 617:	learn: 0.3278958	total: 42.5s	remaining: 9.08s
# 618:	learn: 0.3274588	total: 42.6s	remaining: 9.01s
# 619:	learn: 0.3272097	total: 42.6s	remaining: 8.94s
# 620:	learn: 0.3270608	total: 42.7s	remaining: 8.87s
# 621:	learn: 0.3267765	total: 42.8s	remaining: 8.8s
# 622:	learn: 0.3264486	total: 42.9s	remaining: 8.74s
# 623:	learn: 0.3259971	total: 42.9s	remaining: 8.67s
# 624:	learn: 0.3258004	total: 43s	remaining: 8.6s
# 625:	learn: 0.3252875	total: 43.1s	remaining: 8.53s
# 626:	learn: 0.3250317	total: 43.2s	remaining: 8.47s
# 627:	learn: 0.3245886	total: 43.2s	remaining: 8.4s
# 628:	learn: 0.3242445	total: 43.3s	remaining: 8.33s
# 629:	learn: 0.3239598	total: 43.4s	remaining: 8.27s
# 630:	learn: 0.3235899	total: 43.5s	remaining: 8.2s
# 631:	learn: 0.3232477	total: 43.6s	remaining: 8.13s
# 632:	learn: 0.3226068	total: 43.6s	remaining: 8.06s
# 633:	learn: 0.3222495	total: 43.7s	remaining: 8s
# 634:	learn: 0.3218936	total: 43.8s	remaining: 7.93s
# 635:	learn: 0.3215775	total: 43.8s	remaining: 7.86s
# 636:	learn: 0.3212112	total: 43.9s	remaining: 7.79s
# 637:	learn: 0.3208428	total: 44s	remaining: 7.73s
# 638:	learn: 0.3202558	total: 44.1s	remaining: 7.66s
# 639:	learn: 0.3199987	total: 44.2s	remaining: 7.59s
# 640:	learn: 0.3196412	total: 44.3s	remaining: 7.52s
# 641:	learn: 0.3192389	total: 44.3s	remaining: 7.46s
# 642:	learn: 0.3188539	total: 44.4s	remaining: 7.39s
# 643:	learn: 0.3185295	total: 44.5s	remaining: 7.32s
# 644:	learn: 0.3184092	total: 44.5s	remaining: 7.25s
# 645:	learn: 0.3183846	total: 44.6s	remaining: 7.18s
# 646:	learn: 0.3181199	total: 44.7s	remaining: 7.11s
# 647:	learn: 0.3176619	total: 44.8s	remaining: 7.04s
# 648:	learn: 0.3170033	total: 44.8s	remaining: 6.97s
# 649:	learn: 0.3165723	total: 44.9s	remaining: 6.91s
# 650:	learn: 0.3160671	total: 45s	remaining: 6.84s
# 651:	learn: 0.3156935	total: 45s	remaining: 6.77s
# 652:	learn: 0.3153027	total: 45.1s	remaining: 6.7s
# 653:	learn: 0.3148260	total: 45.2s	remaining: 6.63s
# 654:	learn: 0.3144450	total: 45.2s	remaining: 6.56s
# 655:	learn: 0.3141139	total: 45.3s	remaining: 6.49s
# 656:	learn: 0.3137908	total: 45.4s	remaining: 6.42s
# 657:	learn: 0.3132775	total: 45.4s	remaining: 6.35s
# 658:	learn: 0.3129592	total: 45.5s	remaining: 6.28s
# 659:	learn: 0.3126328	total: 45.6s	remaining: 6.21s
# 660:	learn: 0.3121953	total: 45.6s	remaining: 6.14s
# 661:	learn: 0.3118319	total: 45.7s	remaining: 6.07s
# 662:	learn: 0.3113790	total: 45.8s	remaining: 6s
# 663:	learn: 0.3110444	total: 45.8s	remaining: 5.93s
# 664:	learn: 0.3106533	total: 45.9s	remaining: 5.87s
# 665:	learn: 0.3103607	total: 46s	remaining: 5.8s
# 666:	learn: 0.3101680	total: 46s	remaining: 5.73s
# 667:	learn: 0.3098522	total: 46.1s	remaining: 5.66s
# 668:	learn: 0.3094976	total: 46.2s	remaining: 5.59s
# 669:	learn: 0.3090841	total: 46.2s	remaining: 5.52s
# 670:	learn: 0.3088989	total: 46.3s	remaining: 5.45s
# 671:	learn: 0.3088775	total: 46.4s	remaining: 5.38s
# 672:	learn: 0.3086096	total: 46.4s	remaining: 5.31s
# 673:	learn: 0.3082782	total: 46.5s	remaining: 5.24s
# 674:	learn: 0.3077678	total: 46.6s	remaining: 5.18s
# 675:	learn: 0.3074551	total: 46.7s	remaining: 5.11s
# 676:	learn: 0.3070995	total: 46.7s	remaining: 5.04s
# 677:	learn: 0.3068040	total: 46.8s	remaining: 4.97s
# 678:	learn: 0.3064722	total: 46.9s	remaining: 4.9s
# 679:	learn: 0.3061292	total: 46.9s	remaining: 4.83s
# 680:	learn: 0.3056785	total: 47s	remaining: 4.76s
# 681:	learn: 0.3054598	total: 47.1s	remaining: 4.7s
# 682:	learn: 0.3051757	total: 47.2s	remaining: 4.63s
# 683:	learn: 0.3049270	total: 47.2s	remaining: 4.56s
# 684:	learn: 0.3044293	total: 47.3s	remaining: 4.49s
# 685:	learn: 0.3039841	total: 47.4s	remaining: 4.42s
# 686:	learn: 0.3036275	total: 47.5s	remaining: 4.36s
# 687:	learn: 0.3032161	total: 47.6s	remaining: 4.29s
# 688:	learn: 0.3026773	total: 47.6s	remaining: 4.22s
# 689:	learn: 0.3026458	total: 47.7s	remaining: 4.15s
# 690:	learn: 0.3022163	total: 47.8s	remaining: 4.08s
# 691:	learn: 0.3016144	total: 47.9s	remaining: 4.01s
# 692:	learn: 0.3015898	total: 48s	remaining: 3.95s
# 693:	learn: 0.3012119	total: 48.1s	remaining: 3.88s
# 694:	learn: 0.3008846	total: 48.1s	remaining: 3.81s
# 695:	learn: 0.3005281	total: 48.2s	remaining: 3.74s
# 696:	learn: 0.3001080	total: 48.3s	remaining: 3.67s
# 697:	learn: 0.2997198	total: 48.4s	remaining: 3.6s
# 698:	learn: 0.2996810	total: 48.4s	remaining: 3.53s
# 699:	learn: 0.2991773	total: 48.5s	remaining: 3.47s
# 700:	learn: 0.2991589	total: 48.6s	remaining: 3.4s
# 701:	learn: 0.2991430	total: 48.7s	remaining: 3.33s
# 702:	learn: 0.2989125	total: 48.8s	remaining: 3.26s
# 703:	learn: 0.2987116	total: 48.8s	remaining: 3.19s
# 704:	learn: 0.2983518	total: 48.9s	remaining: 3.12s
# 705:	learn: 0.2980002	total: 49s	remaining: 3.05s
# 706:	learn: 0.2976004	total: 49.1s	remaining: 2.98s
# 707:	learn: 0.2972947	total: 49.1s	remaining: 2.91s
# 708:	learn: 0.2968422	total: 49.2s	remaining: 2.85s
# 709:	learn: 0.2963656	total: 49.3s	remaining: 2.78s
# 710:	learn: 0.2959636	total: 49.4s	remaining: 2.71s
# 711:	learn: 0.2956586	total: 49.5s	remaining: 2.64s
# 712:	learn: 0.2953768	total: 49.5s	remaining: 2.57s
# 713:	learn: 0.2951232	total: 49.6s	remaining: 2.5s
# 714:	learn: 0.2946070	total: 49.7s	remaining: 2.43s
# 715:	learn: 0.2942460	total: 49.8s	remaining: 2.36s
# 716:	learn: 0.2939312	total: 49.8s	remaining: 2.29s
# 717:	learn: 0.2936577	total: 49.9s	remaining: 2.22s
# 718:	learn: 0.2933854	total: 50s	remaining: 2.15s
# 719:	learn: 0.2930177	total: 50.1s	remaining: 2.09s
# 720:	learn: 0.2927870	total: 50.2s	remaining: 2.02s
# 721:	learn: 0.2927646	total: 50.2s	remaining: 1.95s
# 722:	learn: 0.2924667	total: 50.3s	remaining: 1.88s
# 723:	learn: 0.2922321	total: 50.4s	remaining: 1.81s
# 724:	learn: 0.2919599	total: 50.5s	remaining: 1.74s
# 725:	learn: 0.2915134	total: 50.6s	remaining: 1.67s
# 726:	learn: 0.2911101	total: 50.7s	remaining: 1.6s
# 727:	learn: 0.2907502	total: 50.7s	remaining: 1.53s
# 728:	learn: 0.2903566	total: 50.8s	remaining: 1.46s
# 729:	learn: 0.2901097	total: 50.9s	remaining: 1.39s
# 730:	learn: 0.2898780	total: 50.9s	remaining: 1.32s
# 731:	learn: 0.2895693	total: 51s	remaining: 1.25s
# 732:	learn: 0.2892186	total: 51.1s	remaining: 1.18s
# 733:	learn: 0.2888297	total: 51.2s	remaining: 1.11s
# 734:	learn: 0.2885702	total: 51.3s	remaining: 1.04s
# 735:	learn: 0.2882746	total: 51.3s	remaining: 977ms
# 736:	learn: 0.2879913	total: 51.4s	remaining: 907ms
# 737:	learn: 0.2874923	total: 51.5s	remaining: 838ms
# 738:	learn: 0.2871121	total: 51.6s	remaining: 769ms
# 739:	learn: 0.2866079	total: 51.7s	remaining: 699ms
# 740:	learn: 0.2861979	total: 51.8s	remaining: 629ms
# 741:	learn: 0.2858845	total: 51.9s	remaining: 559ms
# 742:	learn: 0.2855741	total: 52s	remaining: 490ms
# 743:	learn: 0.2852318	total: 52s	remaining: 420ms
# 744:	learn: 0.2849821	total: 52.1s	remaining: 350ms
# 745:	learn: 0.2846448	total: 52.2s	remaining: 280ms
# 746:	learn: 0.2843981	total: 52.3s	remaining: 210ms
# 747:	learn: 0.2840420	total: 52.4s	remaining: 140ms
# 748:	learn: 0.2836739	total: 52.5s	remaining: 70ms
# 749:	learn: 0.2833836	total: 52.5s	remaining: 0us
# 0:	learn: 0.9758647	total: 130ms	remaining: 1m 37s
# 1:	learn: 0.9568197	total: 201ms	remaining: 1m 15s
# 2:	learn: 0.9386068	total: 289ms	remaining: 1m 11s
# 3:	learn: 0.9233441	total: 386ms	remaining: 1m 11s
# 4:	learn: 0.9063518	total: 463ms	remaining: 1m 8s
# 5:	learn: 0.8912345	total: 548ms	remaining: 1m 7s
# 6:	learn: 0.8783980	total: 654ms	remaining: 1m 9s
# 7:	learn: 0.8665814	total: 737ms	remaining: 1m 8s
# 8:	learn: 0.8557436	total: 826ms	remaining: 1m 7s
# 9:	learn: 0.8454672	total: 918ms	remaining: 1m 7s
# 10:	learn: 0.8367042	total: 997ms	remaining: 1m 6s
# 11:	learn: 0.8294423	total: 1.08s	remaining: 1m 6s
# 12:	learn: 0.8216692	total: 1.17s	remaining: 1m 6s
# 13:	learn: 0.8145131	total: 1.26s	remaining: 1m 6s
# 14:	learn: 0.8073303	total: 1.34s	remaining: 1m 5s
# 15:	learn: 0.8005838	total: 1.45s	remaining: 1m 6s
# 16:	learn: 0.7946261	total: 1.54s	remaining: 1m 6s
# 17:	learn: 0.7885786	total: 1.64s	remaining: 1m 6s
# 18:	learn: 0.7831674	total: 1.75s	remaining: 1m 7s
# 19:	learn: 0.7788890	total: 1.86s	remaining: 1m 8s
# 20:	learn: 0.7739585	total: 1.95s	remaining: 1m 7s
# 21:	learn: 0.7703969	total: 2.04s	remaining: 1m 7s
# 22:	learn: 0.7656025	total: 2.12s	remaining: 1m 7s
# 23:	learn: 0.7608327	total: 2.2s	remaining: 1m 6s
# 24:	learn: 0.7572187	total: 2.31s	remaining: 1m 7s
# 25:	learn: 0.7540558	total: 2.45s	remaining: 1m 8s
# 26:	learn: 0.7494773	total: 2.53s	remaining: 1m 7s
# 27:	learn: 0.7458671	total: 2.61s	remaining: 1m 7s
# 28:	learn: 0.7424676	total: 2.7s	remaining: 1m 7s
# 29:	learn: 0.7392742	total: 2.79s	remaining: 1m 6s
# 30:	learn: 0.7365259	total: 2.88s	remaining: 1m 6s
# 31:	learn: 0.7337330	total: 2.98s	remaining: 1m 6s
# 32:	learn: 0.7306516	total: 3.05s	remaining: 1m 6s
# 33:	learn: 0.7282712	total: 3.14s	remaining: 1m 6s
# 34:	learn: 0.7264405	total: 3.23s	remaining: 1m 5s
# 35:	learn: 0.7249545	total: 3.31s	remaining: 1m 5s
# 36:	learn: 0.7221198	total: 3.4s	remaining: 1m 5s
# 37:	learn: 0.7196672	total: 3.49s	remaining: 1m 5s
# 38:	learn: 0.7171628	total: 3.58s	remaining: 1m 5s
# 39:	learn: 0.7143764	total: 3.66s	remaining: 1m 5s
# 40:	learn: 0.7125627	total: 3.76s	remaining: 1m 5s
# 41:	learn: 0.7108774	total: 3.84s	remaining: 1m 4s
# 42:	learn: 0.7082656	total: 3.92s	remaining: 1m 4s
# 43:	learn: 0.7060740	total: 4.01s	remaining: 1m 4s
# 44:	learn: 0.7045693	total: 4.08s	remaining: 1m 3s
# 45:	learn: 0.7024994	total: 4.14s	remaining: 1m 3s
# 46:	learn: 0.7000006	total: 4.23s	remaining: 1m 3s
# 47:	learn: 0.6985958	total: 4.32s	remaining: 1m 3s
# 48:	learn: 0.6972526	total: 4.41s	remaining: 1m 3s
# 49:	learn: 0.6956044	total: 4.51s	remaining: 1m 3s
# 50:	learn: 0.6944313	total: 4.59s	remaining: 1m 2s
# 51:	learn: 0.6933184	total: 4.7s	remaining: 1m 3s
# 52:	learn: 0.6916614	total: 4.78s	remaining: 1m 2s
# 53:	learn: 0.6902039	total: 4.86s	remaining: 1m 2s
# 54:	learn: 0.6884658	total: 4.93s	remaining: 1m 2s
# 55:	learn: 0.6876843	total: 5.01s	remaining: 1m 2s
# 56:	learn: 0.6862393	total: 5.1s	remaining: 1m 1s
# 57:	learn: 0.6847871	total: 5.17s	remaining: 1m 1s
# 58:	learn: 0.6831879	total: 5.25s	remaining: 1m 1s
# 59:	learn: 0.6819810	total: 5.33s	remaining: 1m 1s
# 60:	learn: 0.6803533	total: 5.41s	remaining: 1m 1s
# 61:	learn: 0.6792714	total: 5.49s	remaining: 1m
# 62:	learn: 0.6779601	total: 5.57s	remaining: 1m
# 63:	learn: 0.6767741	total: 5.64s	remaining: 1m
# 64:	learn: 0.6755850	total: 5.72s	remaining: 1m
# 65:	learn: 0.6740128	total: 5.79s	remaining: 60s
# 66:	learn: 0.6731823	total: 5.86s	remaining: 59.7s
# 67:	learn: 0.6721160	total: 5.93s	remaining: 59.4s
# 68:	learn: 0.6710044	total: 6s	remaining: 59.2s
# 69:	learn: 0.6703295	total: 6.07s	remaining: 59s
# 70:	learn: 0.6690910	total: 6.13s	remaining: 58.6s
# 71:	learn: 0.6680189	total: 6.19s	remaining: 58.3s
# 72:	learn: 0.6665605	total: 6.27s	remaining: 58.1s
# 73:	learn: 0.6657027	total: 6.33s	remaining: 57.8s
# 74:	learn: 0.6647918	total: 6.4s	remaining: 57.6s
# 75:	learn: 0.6639875	total: 6.48s	remaining: 57.5s
# 76:	learn: 0.6629221	total: 6.55s	remaining: 57.3s
# 77:	learn: 0.6623496	total: 6.63s	remaining: 57.1s
# 78:	learn: 0.6612959	total: 6.7s	remaining: 56.9s
# 79:	learn: 0.6601779	total: 6.76s	remaining: 56.6s
# 80:	learn: 0.6593981	total: 6.83s	remaining: 56.4s
# 81:	learn: 0.6585031	total: 6.91s	remaining: 56.3s
# 82:	learn: 0.6571146	total: 6.97s	remaining: 56s
# 83:	learn: 0.6560454	total: 7.04s	remaining: 55.8s
# 84:	learn: 0.6548103	total: 7.12s	remaining: 55.7s
# 85:	learn: 0.6533388	total: 7.19s	remaining: 55.5s
# 86:	learn: 0.6525290	total: 7.25s	remaining: 55.3s
# 87:	learn: 0.6511292	total: 7.32s	remaining: 55.1s
# 88:	learn: 0.6498590	total: 7.39s	remaining: 54.9s
# 89:	learn: 0.6493344	total: 7.46s	remaining: 54.7s
# 90:	learn: 0.6482089	total: 7.53s	remaining: 54.5s
# 91:	learn: 0.6470360	total: 7.59s	remaining: 54.3s
# 92:	learn: 0.6461621	total: 7.67s	remaining: 54.2s
# 93:	learn: 0.6448457	total: 7.74s	remaining: 54s
# 94:	learn: 0.6429918	total: 7.81s	remaining: 53.8s
# 95:	learn: 0.6420341	total: 7.88s	remaining: 53.7s
# 96:	learn: 0.6412036	total: 7.95s	remaining: 53.6s
# 97:	learn: 0.6399713	total: 8.03s	remaining: 53.4s
# 98:	learn: 0.6391152	total: 8.11s	remaining: 53.3s
# 99:	learn: 0.6378104	total: 8.2s	remaining: 53.3s
# 100:	learn: 0.6365384	total: 8.29s	remaining: 53.3s
# 101:	learn: 0.6349086	total: 8.37s	remaining: 53.2s
# 102:	learn: 0.6337700	total: 8.44s	remaining: 53s
# 103:	learn: 0.6331450	total: 8.51s	remaining: 52.9s
# 104:	learn: 0.6321428	total: 8.58s	remaining: 52.7s
# 105:	learn: 0.6309938	total: 8.68s	remaining: 52.8s
# 106:	learn: 0.6298737	total: 8.75s	remaining: 52.6s
# 107:	learn: 0.6284644	total: 8.82s	remaining: 52.5s
# 108:	learn: 0.6272400	total: 8.9s	remaining: 52.3s
# 109:	learn: 0.6260575	total: 8.97s	remaining: 52.2s
# 110:	learn: 0.6250449	total: 9.04s	remaining: 52s
# 111:	learn: 0.6239465	total: 9.12s	remaining: 51.9s
# 112:	learn: 0.6232786	total: 9.18s	remaining: 51.8s
# 113:	learn: 0.6223014	total: 9.25s	remaining: 51.6s
# 114:	learn: 0.6204449	total: 9.33s	remaining: 51.5s
# 115:	learn: 0.6196080	total: 9.41s	remaining: 51.4s
# 116:	learn: 0.6184823	total: 9.48s	remaining: 51.3s
# 117:	learn: 0.6176332	total: 9.57s	remaining: 51.2s
# 118:	learn: 0.6169635	total: 9.64s	remaining: 51.1s
# 119:	learn: 0.6159934	total: 9.7s	remaining: 50.9s
# 120:	learn: 0.6145199	total: 9.78s	remaining: 50.8s
# 121:	learn: 0.6126982	total: 9.85s	remaining: 50.7s
# 122:	learn: 0.6113870	total: 9.92s	remaining: 50.6s
# 123:	learn: 0.6098722	total: 9.99s	remaining: 50.4s
# 124:	learn: 0.6087455	total: 10.1s	remaining: 50.3s
# 125:	learn: 0.6073292	total: 10.1s	remaining: 50.2s
# 126:	learn: 0.6065413	total: 10.2s	remaining: 50.2s
# 127:	learn: 0.6055673	total: 10.3s	remaining: 50.1s
# 128:	learn: 0.6037852	total: 10.4s	remaining: 49.9s
# 129:	learn: 0.6025443	total: 10.4s	remaining: 49.8s
# 130:	learn: 0.6011675	total: 10.5s	remaining: 49.7s
# 131:	learn: 0.5995470	total: 10.6s	remaining: 49.6s
# 132:	learn: 0.5980306	total: 10.7s	remaining: 49.4s
# 133:	learn: 0.5970500	total: 10.7s	remaining: 49.4s
# 134:	learn: 0.5957926	total: 10.8s	remaining: 49.2s
# 135:	learn: 0.5940810	total: 10.9s	remaining: 49.1s
# 136:	learn: 0.5926263	total: 10.9s	remaining: 49s
# 137:	learn: 0.5919294	total: 11s	remaining: 48.9s
# 138:	learn: 0.5916116	total: 11.1s	remaining: 48.8s
# 139:	learn: 0.5904277	total: 11.2s	remaining: 48.6s
# 140:	learn: 0.5902303	total: 11.2s	remaining: 48.5s
# 141:	learn: 0.5888664	total: 11.3s	remaining: 48.4s
# 142:	learn: 0.5874310	total: 11.4s	remaining: 48.3s
# 143:	learn: 0.5872210	total: 11.4s	remaining: 48.2s
# 144:	learn: 0.5858194	total: 11.5s	remaining: 48.1s
# 145:	learn: 0.5855185	total: 11.6s	remaining: 47.9s
# 146:	learn: 0.5836956	total: 11.7s	remaining: 47.9s
# 147:	learn: 0.5824441	total: 11.7s	remaining: 47.7s
# 148:	learn: 0.5815006	total: 11.8s	remaining: 47.6s
# 149:	learn: 0.5803680	total: 11.9s	remaining: 47.5s
# 150:	learn: 0.5792555	total: 12s	remaining: 47.4s
# 151:	learn: 0.5780800	total: 12s	remaining: 47.3s
# 152:	learn: 0.5772768	total: 12.1s	remaining: 47.2s
# 153:	learn: 0.5770482	total: 12.2s	remaining: 47s
# 154:	learn: 0.5760769	total: 12.2s	remaining: 47s
# 155:	learn: 0.5751531	total: 12.3s	remaining: 46.9s
# 156:	learn: 0.5740156	total: 12.4s	remaining: 46.7s
# 157:	learn: 0.5727350	total: 12.4s	remaining: 46.6s
# 158:	learn: 0.5714509	total: 12.5s	remaining: 46.5s
# 159:	learn: 0.5706785	total: 12.6s	remaining: 46.4s
# 160:	learn: 0.5693066	total: 12.7s	remaining: 46.5s
# 161:	learn: 0.5677552	total: 12.8s	remaining: 46.5s
# 162:	learn: 0.5667221	total: 12.9s	remaining: 46.6s
# 163:	learn: 0.5665854	total: 13s	remaining: 46.5s
# 164:	learn: 0.5656578	total: 13.1s	remaining: 46.4s
# 165:	learn: 0.5649709	total: 13.2s	remaining: 46.4s
# 166:	learn: 0.5639421	total: 13.3s	remaining: 46.3s
# 167:	learn: 0.5630597	total: 13.3s	remaining: 46.2s
# 168:	learn: 0.5621134	total: 13.4s	remaining: 46s
# 169:	learn: 0.5614342	total: 13.5s	remaining: 45.9s
# 170:	learn: 0.5606384	total: 13.5s	remaining: 45.8s
# 171:	learn: 0.5598573	total: 13.6s	remaining: 45.7s
# 172:	learn: 0.5587797	total: 13.7s	remaining: 45.6s
# 173:	learn: 0.5573630	total: 13.7s	remaining: 45.5s
# 174:	learn: 0.5572596	total: 13.8s	remaining: 45.4s
# 175:	learn: 0.5563247	total: 13.9s	remaining: 45.3s
# 176:	learn: 0.5554022	total: 14s	remaining: 45.3s
# 177:	learn: 0.5546859	total: 14.1s	remaining: 45.2s
# 178:	learn: 0.5544668	total: 14.1s	remaining: 45.1s
# 179:	learn: 0.5533156	total: 14.2s	remaining: 45s
# 180:	learn: 0.5522931	total: 14.3s	remaining: 44.9s
# 181:	learn: 0.5512179	total: 14.3s	remaining: 44.7s
# 182:	learn: 0.5502872	total: 14.4s	remaining: 44.6s
# ...
# 454:	learn: 0.3597542	total: 34.6s	remaining: 22.5s
# 455:	learn: 0.3595118	total: 34.7s	remaining: 22.4s
# 456:	learn: 0.3589536	total: 34.8s	remaining: 22.3s
# 457:	learn: 0.3585386	total: 34.9s	remaining: 22.2s
# 458:	learn: 0.3582308	total: 34.9s	remaining: 22.1s
# 459:	learn: 0.3575353	total: 35s	remaining: 22.1s
# 460:	learn: 0.3569978	total: 35s	remaining: 22s
# 461:	learn: 0.3565431	total: 35.1s	remaining: 21.9s
# 462:	learn: 0.3557411	total: 35.2s	remaining: 21.8s
# 463:	learn: 0.3553213	total: 35.3s	remaining: 21.7s
# 464:	learn: 0.3544004	total: 35.3s	remaining: 21.7s
# 465:	learn: 0.3537846	total: 35.4s	remaining: 21.6s
# 466:	learn: 0.3532361	total: 35.5s	remaining: 21.5s
# 467:	learn: 0.3528432	total: 35.5s	remaining: 21.4s
# 468:	learn: 0.3523972	total: 35.6s	remaining: 21.3s
# 469:	learn: 0.3516616	total: 35.7s	remaining: 21.3s
# 470:	learn: 0.3511441	total: 35.7s	remaining: 21.2s
# 471:	learn: 0.3507603	total: 35.8s	remaining: 21.1s
# 472:	learn: 0.3503598	total: 35.9s	remaining: 21s
# 473:	learn: 0.3498168	total: 36s	remaining: 21s
# 474:	learn: 0.3491371	total: 36.1s	remaining: 20.9s
# 475:	learn: 0.3486320	total: 36.1s	remaining: 20.8s
# 476:	learn: 0.3479955	total: 36.2s	remaining: 20.7s
# 477:	learn: 0.3474809	total: 36.3s	remaining: 20.7s
# 478:	learn: 0.3470557	total: 36.4s	remaining: 20.6s
# 479:	learn: 0.3464574	total: 36.4s	remaining: 20.5s
# 480:	learn: 0.3459565	total: 36.5s	remaining: 20.4s
# 481:	learn: 0.3454819	total: 36.6s	remaining: 20.3s
# 482:	learn: 0.3449456	total: 36.7s	remaining: 20.3s
# 483:	learn: 0.3444512	total: 36.8s	remaining: 20.2s
# 484:	learn: 0.3441418	total: 36.8s	remaining: 20.1s
# 485:	learn: 0.3436007	total: 36.9s	remaining: 20s
# 486:	learn: 0.3430167	total: 37s	remaining: 20s
# 487:	learn: 0.3425715	total: 37s	remaining: 19.9s
# 488:	learn: 0.3420366	total: 37.1s	remaining: 19.8s
# 489:	learn: 0.3413219	total: 37.2s	remaining: 19.7s
# 490:	learn: 0.3407829	total: 37.2s	remaining: 19.6s
# 491:	learn: 0.3403976	total: 37.3s	remaining: 19.6s
# 492:	learn: 0.3396932	total: 37.4s	remaining: 19.5s
# 493:	learn: 0.3391192	total: 37.5s	remaining: 19.4s
# 494:	learn: 0.3384207	total: 37.6s	remaining: 19.3s
# 495:	learn: 0.3378317	total: 37.6s	remaining: 19.3s
# 496:	learn: 0.3372995	total: 37.7s	remaining: 19.2s
# 497:	learn: 0.3368993	total: 37.8s	remaining: 19.1s
# 498:	learn: 0.3366112	total: 37.9s	remaining: 19s
# 499:	learn: 0.3361180	total: 37.9s	remaining: 19s
# 500:	learn: 0.3358557	total: 38s	remaining: 18.9s
# 501:	learn: 0.3358085	total: 38.1s	remaining: 18.8s
# 502:	learn: 0.3353076	total: 38.2s	remaining: 18.7s
# 503:	learn: 0.3348828	total: 38.2s	remaining: 18.7s
# 504:	learn: 0.3343622	total: 38.3s	remaining: 18.6s
# 505:	learn: 0.3338275	total: 38.4s	remaining: 18.5s
# 506:	learn: 0.3334007	total: 38.4s	remaining: 18.4s
# 507:	learn: 0.3326988	total: 38.5s	remaining: 18.3s
# 508:	learn: 0.3321620	total: 38.6s	remaining: 18.3s
# 509:	learn: 0.3316350	total: 38.6s	remaining: 18.2s
# 510:	learn: 0.3309586	total: 38.7s	remaining: 18.1s
# 511:	learn: 0.3303282	total: 38.8s	remaining: 18s
# 512:	learn: 0.3299101	total: 38.9s	remaining: 17.9s
# 513:	learn: 0.3292608	total: 38.9s	remaining: 17.9s
# 514:	learn: 0.3289169	total: 39s	remaining: 17.8s
# 515:	learn: 0.3285328	total: 39.1s	remaining: 17.7s
# 516:	learn: 0.3279826	total: 39.1s	remaining: 17.6s
# 517:	learn: 0.3273800	total: 39.2s	remaining: 17.6s
# 518:	learn: 0.3269226	total: 39.3s	remaining: 17.5s
# 519:	learn: 0.3263135	total: 39.4s	remaining: 17.4s
# 520:	learn: 0.3258441	total: 39.4s	remaining: 17.3s
# 521:	learn: 0.3254332	total: 39.5s	remaining: 17.3s
# 522:	learn: 0.3247906	total: 39.6s	remaining: 17.2s
# 523:	learn: 0.3247422	total: 39.6s	remaining: 17.1s
# 524:	learn: 0.3242254	total: 39.7s	remaining: 17s
# 525:	learn: 0.3235714	total: 39.8s	remaining: 16.9s
# 526:	learn: 0.3231544	total: 39.9s	remaining: 16.9s
# 527:	learn: 0.3229243	total: 39.9s	remaining: 16.8s
# 528:	learn: 0.3224937	total: 40s	remaining: 16.7s
# 529:	learn: 0.3220047	total: 40.1s	remaining: 16.6s
# 530:	learn: 0.3213752	total: 40.1s	remaining: 16.6s
# 531:	learn: 0.3206875	total: 40.2s	remaining: 16.5s
# 532:	learn: 0.3201709	total: 40.3s	remaining: 16.4s
# 533:	learn: 0.3196957	total: 40.4s	remaining: 16.3s
# 534:	learn: 0.3191673	total: 40.4s	remaining: 16.2s
# 535:	learn: 0.3185095	total: 40.5s	remaining: 16.2s
# 536:	learn: 0.3181309	total: 40.6s	remaining: 16.1s
# 537:	learn: 0.3178249	total: 40.6s	remaining: 16s
# 538:	learn: 0.3174177	total: 40.7s	remaining: 15.9s
# 539:	learn: 0.3169646	total: 40.8s	remaining: 15.9s
# 540:	learn: 0.3164773	total: 40.9s	remaining: 15.8s
# 541:	learn: 0.3158035	total: 40.9s	remaining: 15.7s
# 542:	learn: 0.3154343	total: 41s	remaining: 15.6s
# 543:	learn: 0.3150016	total: 41.1s	remaining: 15.6s
# 544:	learn: 0.3145621	total: 41.2s	remaining: 15.5s
# 545:	learn: 0.3142486	total: 41.2s	remaining: 15.4s
# 546:	learn: 0.3138285	total: 41.3s	remaining: 15.3s
# 547:	learn: 0.3136353	total: 41.4s	remaining: 15.3s
# 548:	learn: 0.3131291	total: 41.5s	remaining: 15.2s
# 549:	learn: 0.3127181	total: 41.5s	remaining: 15.1s
# 550:	learn: 0.3122397	total: 41.6s	remaining: 15s
# 551:	learn: 0.3117868	total: 41.7s	remaining: 15s
# 552:	learn: 0.3112964	total: 41.8s	remaining: 14.9s
# 553:	learn: 0.3109540	total: 41.8s	remaining: 14.8s
# 554:	learn: 0.3105031	total: 41.9s	remaining: 14.7s
# 555:	learn: 0.3099802	total: 42s	remaining: 14.7s
# 556:	learn: 0.3096732	total: 42.1s	remaining: 14.6s
# 557:	learn: 0.3092196	total: 42.1s	remaining: 14.5s
# 558:	learn: 0.3087648	total: 42.2s	remaining: 14.4s
# 559:	learn: 0.3082082	total: 42.3s	remaining: 14.3s
# 560:	learn: 0.3076919	total: 42.4s	remaining: 14.3s
# 561:	learn: 0.3071818	total: 42.5s	remaining: 14.2s
# 562:	learn: 0.3066705	total: 42.5s	remaining: 14.1s
# 563:	learn: 0.3062113	total: 42.6s	remaining: 14s
# 564:	learn: 0.3054540	total: 42.7s	remaining: 14s
# 565:	learn: 0.3048551	total: 42.7s	remaining: 13.9s
# 566:	learn: 0.3044994	total: 42.8s	remaining: 13.8s
# 567:	learn: 0.3040533	total: 42.9s	remaining: 13.7s
# 568:	learn: 0.3035525	total: 42.9s	remaining: 13.7s
# 569:	learn: 0.3030339	total: 43s	remaining: 13.6s
# 570:	learn: 0.3025152	total: 43.1s	remaining: 13.5s
# 571:	learn: 0.3020234	total: 43.2s	remaining: 13.4s
# 572:	learn: 0.3014015	total: 43.2s	remaining: 13.4s
# 573:	learn: 0.3010144	total: 43.3s	remaining: 13.3s
# 574:	learn: 0.3006071	total: 43.4s	remaining: 13.2s
# 575:	learn: 0.2998969	total: 43.4s	remaining: 13.1s
# 576:	learn: 0.2992432	total: 43.5s	remaining: 13.1s
# 577:	learn: 0.2987516	total: 43.6s	remaining: 13s
# 578:	learn: 0.2984911	total: 43.7s	remaining: 12.9s
# 579:	learn: 0.2982226	total: 43.8s	remaining: 12.8s
# 580:	learn: 0.2981553	total: 43.8s	remaining: 12.8s
# 581:	learn: 0.2978564	total: 43.9s	remaining: 12.7s
# 582:	learn: 0.2974896	total: 44s	remaining: 12.6s
# 583:	learn: 0.2971490	total: 44.1s	remaining: 12.5s
# 584:	learn: 0.2966830	total: 44.1s	remaining: 12.4s
# 585:	learn: 0.2960102	total: 44.2s	remaining: 12.4s
# 586:	learn: 0.2955462	total: 44.3s	remaining: 12.3s
# 587:	learn: 0.2950018	total: 44.4s	remaining: 12.2s
# 588:	learn: 0.2945361	total: 44.4s	remaining: 12.1s
# 589:	learn: 0.2940521	total: 44.5s	remaining: 12.1s
# 590:	learn: 0.2936788	total: 44.6s	remaining: 12s
# 591:	learn: 0.2933304	total: 44.7s	remaining: 11.9s
# 592:	learn: 0.2930864	total: 44.7s	remaining: 11.8s
# 593:	learn: 0.2926365	total: 44.8s	remaining: 11.8s
# 594:	learn: 0.2923042	total: 44.9s	remaining: 11.7s
# 595:	learn: 0.2918961	total: 44.9s	remaining: 11.6s
# 596:	learn: 0.2914728	total: 45s	remaining: 11.5s
# 597:	learn: 0.2911413	total: 45.1s	remaining: 11.5s
# 598:	learn: 0.2906523	total: 45.2s	remaining: 11.4s
# 599:	learn: 0.2903724	total: 45.2s	remaining: 11.3s
# 600:	learn: 0.2903032	total: 45.3s	remaining: 11.2s
# 601:	learn: 0.2899268	total: 45.4s	remaining: 11.2s
# 602:	learn: 0.2894429	total: 45.4s	remaining: 11.1s
# 603:	learn: 0.2891620	total: 45.5s	remaining: 11s
# 604:	learn: 0.2887416	total: 45.6s	remaining: 10.9s
# 605:	learn: 0.2882112	total: 45.7s	remaining: 10.8s
# 606:	learn: 0.2879543	total: 45.7s	remaining: 10.8s
# 607:	learn: 0.2876988	total: 45.8s	remaining: 10.7s
# 608:	learn: 0.2872782	total: 45.9s	remaining: 10.6s
# 609:	learn: 0.2870706	total: 45.9s	remaining: 10.5s
# 610:	learn: 0.2866047	total: 46s	remaining: 10.5s
# 611:	learn: 0.2861020	total: 46.1s	remaining: 10.4s
# 612:	learn: 0.2855326	total: 46.2s	remaining: 10.3s
# 613:	learn: 0.2852269	total: 46.3s	remaining: 10.2s
# 614:	learn: 0.2851847	total: 46.3s	remaining: 10.2s
# 615:	learn: 0.2846343	total: 46.4s	remaining: 10.1s
# 616:	learn: 0.2842422	total: 46.5s	remaining: 10s
# 617:	learn: 0.2838647	total: 46.6s	remaining: 9.94s
# 618:	learn: 0.2833020	total: 46.6s	remaining: 9.87s
# 619:	learn: 0.2829598	total: 46.7s	remaining: 9.79s
# 620:	learn: 0.2825804	total: 46.8s	remaining: 9.71s
# 621:	learn: 0.2821124	total: 46.8s	remaining: 9.64s
# 622:	learn: 0.2816382	total: 46.9s	remaining: 9.56s
# 623:	learn: 0.2811301	total: 47s	remaining: 9.49s
# 624:	learn: 0.2806100	total: 47.1s	remaining: 9.41s
# 625:	learn: 0.2803292	total: 47.1s	remaining: 9.34s
# 626:	learn: 0.2799042	total: 47.2s	remaining: 9.26s
# 627:	learn: 0.2795115	total: 47.3s	remaining: 9.19s
# 628:	learn: 0.2791171	total: 47.4s	remaining: 9.11s
# 629:	learn: 0.2785978	total: 47.4s	remaining: 9.04s
# 630:	learn: 0.2781363	total: 47.5s	remaining: 8.96s
# 631:	learn: 0.2778149	total: 47.6s	remaining: 8.88s
# 632:	learn: 0.2774681	total: 47.7s	remaining: 8.81s
# 633:	learn: 0.2772180	total: 47.8s	remaining: 8.74s
# 634:	learn: 0.2769301	total: 47.8s	remaining: 8.66s
# 635:	learn: 0.2764969	total: 47.9s	remaining: 8.59s
# 636:	learn: 0.2759820	total: 48s	remaining: 8.51s
# 637:	learn: 0.2753391	total: 48.1s	remaining: 8.44s
# 638:	learn: 0.2750722	total: 48.1s	remaining: 8.36s
# 639:	learn: 0.2747455	total: 48.2s	remaining: 8.28s
# 640:	learn: 0.2744146	total: 48.3s	remaining: 8.21s
# 641:	learn: 0.2739625	total: 48.4s	remaining: 8.13s
# 642:	learn: 0.2734830	total: 48.4s	remaining: 8.06s
# 643:	learn: 0.2729966	total: 48.5s	remaining: 7.98s
# 644:	learn: 0.2725841	total: 48.6s	remaining: 7.91s
# 645:	learn: 0.2722143	total: 48.6s	remaining: 7.83s
# 646:	learn: 0.2719418	total: 48.7s	remaining: 7.75s
# 647:	learn: 0.2715774	total: 48.8s	remaining: 7.68s
# 648:	learn: 0.2711548	total: 48.8s	remaining: 7.6s
# 649:	learn: 0.2707253	total: 48.9s	remaining: 7.52s
# 650:	learn: 0.2703062	total: 49s	remaining: 7.45s
# 651:	learn: 0.2699907	total: 49.1s	remaining: 7.37s
# 652:	learn: 0.2698636	total: 49.1s	remaining: 7.29s
# 653:	learn: 0.2695245	total: 49.2s	remaining: 7.22s
# 654:	learn: 0.2691699	total: 49.2s	remaining: 7.14s
# 655:	learn: 0.2689046	total: 49.3s	remaining: 7.07s
# 656:	learn: 0.2686359	total: 49.4s	remaining: 6.99s
# 657:	learn: 0.2680835	total: 49.5s	remaining: 6.91s
# 658:	learn: 0.2676539	total: 49.5s	remaining: 6.84s
# 659:	learn: 0.2671318	total: 49.6s	remaining: 6.76s
# 660:	learn: 0.2669829	total: 49.6s	remaining: 6.68s
# 661:	learn: 0.2666348	total: 49.7s	remaining: 6.61s
# 662:	learn: 0.2663001	total: 49.8s	remaining: 6.53s
# 663:	learn: 0.2659489	total: 49.9s	remaining: 6.46s
# 664:	learn: 0.2654965	total: 50s	remaining: 6.39s
# 665:	learn: 0.2651292	total: 50s	remaining: 6.31s
# 666:	learn: 0.2649359	total: 50.1s	remaining: 6.24s
# 667:	learn: 0.2647401	total: 50.2s	remaining: 6.16s
# 668:	learn: 0.2643623	total: 50.2s	remaining: 6.08s
# 669:	learn: 0.2640456	total: 50.3s	remaining: 6.01s
# 670:	learn: 0.2635805	total: 50.4s	remaining: 5.93s
# 671:	learn: 0.2633361	total: 50.5s	remaining: 5.86s
# 672:	learn: 0.2628229	total: 50.6s	remaining: 5.79s
# 673:	learn: 0.2624350	total: 50.6s	remaining: 5.71s
# 674:	learn: 0.2621335	total: 50.7s	remaining: 5.64s
# 675:	learn: 0.2616993	total: 50.8s	remaining: 5.56s
# 676:	learn: 0.2612368	total: 50.9s	remaining: 5.49s
# 677:	learn: 0.2609768	total: 51s	remaining: 5.41s
# 678:	learn: 0.2604912	total: 51s	remaining: 5.34s
# 679:	learn: 0.2604427	total: 51.1s	remaining: 5.26s
# 680:	learn: 0.2601223	total: 51.2s	remaining: 5.19s
# 681:	learn: 0.2596201	total: 51.3s	remaining: 5.11s
# 682:	learn: 0.2592082	total: 51.4s	remaining: 5.04s
# 683:	learn: 0.2587887	total: 51.5s	remaining: 4.96s
# 684:	learn: 0.2585067	total: 51.5s	remaining: 4.89s
# 685:	learn: 0.2584813	total: 51.6s	remaining: 4.82s
# 686:	learn: 0.2582275	total: 51.7s	remaining: 4.74s
# 687:	learn: 0.2577670	total: 51.8s	remaining: 4.66s
# 688:	learn: 0.2574959	total: 51.8s	remaining: 4.59s
# 689:	learn: 0.2572099	total: 51.9s	remaining: 4.51s
# 690:	learn: 0.2569337	total: 52s	remaining: 4.44s
# 691:	learn: 0.2566696	total: 52.1s	remaining: 4.36s
# 692:	learn: 0.2561638	total: 52.1s	remaining: 4.29s
# 693:	learn: 0.2558114	total: 52.2s	remaining: 4.21s
# 694:	learn: 0.2554579	total: 52.3s	remaining: 4.14s
# 695:	learn: 0.2551450	total: 52.3s	remaining: 4.06s
# 696:	learn: 0.2548807	total: 52.4s	remaining: 3.98s
# 697:	learn: 0.2545149	total: 52.5s	remaining: 3.91s
# 698:	learn: 0.2541807	total: 52.5s	remaining: 3.83s
# 699:	learn: 0.2536605	total: 52.6s	remaining: 3.76s
# 700:	learn: 0.2533150	total: 52.7s	remaining: 3.68s
# 701:	learn: 0.2528563	total: 52.8s	remaining: 3.61s
# 702:	learn: 0.2523812	total: 52.8s	remaining: 3.53s
# 703:	learn: 0.2519981	total: 52.9s	remaining: 3.46s
# 704:	learn: 0.2514581	total: 53s	remaining: 3.38s
# 705:	learn: 0.2511207	total: 53.1s	remaining: 3.31s
# 706:	learn: 0.2509109	total: 53.1s	remaining: 3.23s
# 707:	learn: 0.2504828	total: 53.2s	remaining: 3.15s
# 708:	learn: 0.2501531	total: 53.3s	remaining: 3.08s
# 709:	learn: 0.2497739	total: 53.3s	remaining: 3s
# 710:	learn: 0.2495335	total: 53.4s	remaining: 2.93s
# 711:	learn: 0.2490385	total: 53.5s	remaining: 2.85s
# 712:	learn: 0.2490194	total: 53.5s	remaining: 2.78s
# 713:	learn: 0.2486661	total: 53.6s	remaining: 2.7s
# 714:	learn: 0.2484129	total: 53.7s	remaining: 2.63s
# 715:	learn: 0.2480320	total: 53.8s	remaining: 2.55s
# 716:	learn: 0.2473756	total: 53.8s	remaining: 2.48s
# 717:	learn: 0.2469775	total: 53.9s	remaining: 2.4s
# 718:	learn: 0.2467147	total: 54s	remaining: 2.33s
# 719:	learn: 0.2462952	total: 54s	remaining: 2.25s
# 720:	learn: 0.2459051	total: 54.1s	remaining: 2.18s
# 721:	learn: 0.2455664	total: 54.2s	remaining: 2.1s
# 722:	learn: 0.2451437	total: 54.3s	remaining: 2.03s
# 723:	learn: 0.2451216	total: 54.4s	remaining: 1.95s
# 724:	learn: 0.2448570	total: 54.5s	remaining: 1.88s
# 725:	learn: 0.2444563	total: 54.5s	remaining: 1.8s
# 726:	learn: 0.2440377	total: 54.6s	remaining: 1.73s
# 727:	learn: 0.2438217	total: 54.7s	remaining: 1.65s
# 728:	learn: 0.2433820	total: 54.7s	remaining: 1.58s
# 729:	learn: 0.2431047	total: 54.8s	remaining: 1.5s
# 730:	learn: 0.2427468	total: 54.9s	remaining: 1.43s
# 731:	learn: 0.2424753	total: 55s	remaining: 1.35s
# 732:	learn: 0.2420901	total: 55s	remaining: 1.28s
# 733:	learn: 0.2416568	total: 55.1s	remaining: 1.2s
# 734:	learn: 0.2414385	total: 55.2s	remaining: 1.13s
# 735:	learn: 0.2410241	total: 55.3s	remaining: 1.05s
# 736:	learn: 0.2406606	total: 55.4s	remaining: 977ms
# 737:	learn: 0.2401801	total: 55.4s	remaining: 902ms
# 738:	learn: 0.2398713	total: 55.5s	remaining: 826ms
# 739:	learn: 0.2395510	total: 55.6s	remaining: 751ms
# 740:	learn: 0.2393281	total: 55.7s	remaining: 676ms
# 741:	learn: 0.2390841	total: 55.7s	remaining: 601ms
# 742:	learn: 0.2387261	total: 55.8s	remaining: 526ms
# 743:	learn: 0.2382860	total: 55.9s	remaining: 451ms
# 744:	learn: 0.2379674	total: 56s	remaining: 376ms
# 745:	learn: 0.2375097	total: 56s	remaining: 300ms
# 746:	learn: 0.2372921	total: 56.1s	remaining: 225ms
# 747:	learn: 0.2372706	total: 56.1s	remaining: 150ms
# 748:	learn: 0.2371519	total: 56.2s	remaining: 75.1ms
# 749:	learn: 0.2367815	total: 56.3s	remaining: 0us
# StackingRegressor(cv=KFold(n_splits=5, random_state=RandomState(MT19937) at 0x1593962A540,
#    shuffle=True),
#                   estimators=[('cat',
#                                <catboost.core.CatBoostRegressor object at 0x0000015939635D00>),
#                               ('lgbm',
#                                LGBMRegressor(colsample_bytree=0.6,
#                                              learning_rate=0.01, max_depth=9,
#                                              n_estimators=1200, num_leaves=15,
#                                              objective='regression',
#                                              reg_alpha=0, reg_lambda=0))],
#                   final_estimator=ElasticNetCV())

# %%
en.final_estimator_.coef_
# Out:
# array([0.48790138, 0.55635312])

# %% [markdown]
# ### MARS (fitted on residuals)

# %% [markdown]
# Calculate training data residuals of ensemble model, and fit MARS model to them. Then, add predicted residuals to the catboost (not ensemble) predictions.

# %%
# Calculate the residuals for training data
resid = log_y - en.predict(X_train)

# Fit a MARS model to the residuals
mars_resid = Earth()
mars_resid.fit(X_train, resid)

# Use the MARS model to predict the residuals for training data
mars_resid_pred = mars_resid.predict(X_train)

# Combine the CatBoost predictions with the MARS predictions for training data
# combined_pred_train = cat.predict(X_train) + mars_resid_pred

# Use the combined predictions on test data (since we don't have true y_test)
combined_pred_test = cat.predict(X_test) + mars_resid.predict(X_test)
# Out:
# C:\Users\rolfe\anaconda3\lib\site-packages\pyearth\earth.py:813: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   pruning_passer.run()
# C:\Users\rolfe\anaconda3\lib\site-packages\pyearth\earth.py:1066: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   coef, resid = np.linalg.lstsq(B, weighted_y[:, i])[0:2]

# %% [markdown]
# ### Predictions

# %%
# Make prediction equal to combined predictions of Catboost and Mars Resid
y_pred = combined_pred_test

# Exponentiate logged y
y_pred = np.exp(y_pred)

# Scale up predictions by 1.30
y_pred = y_pred*1.30

# Clip predictions between 0 and 100
y_pred = np.clip(y_pred,0,100)

#Export to csv
predictions_regression = pd.DataFrame({"id" : test_id, "y": y_pred})
predictions_regression.to_csv("Predictions_Regression.csv",index = False)

# %% [markdown]
# ## A.5) Discussion

# %% [markdown]
# Please provide details of the models/approaches you attempted but encountered challenges or unfavorable outcomes. If feasible, kindly explain the reasons behind their ineffectiveness or lack of success. Additionally, highlight the significant challenges or issues you encountered during the process.

# %% [markdown]
# We attempted to create models using the following methods: Lasso, Neural Networks, XGBoost, AdaBoost, Mars, as well as various ensembles that included combinations of these.
#
# We had some initial breakthroughs ensembling lasso with catboost and lgbm. However, our best eventual models did not include it. We were a bit surprised by the lack of success of neural networks and xgboost. It was incredibly frustrating with neural networks, because we learned about this method in STAT-362 this quarter. We tried employing various tools in order to make the neural network complex, considering that this method has proven to be an industry standard at this point. However, none of our attempts with neural networks were able to accomplish an RMSE below 10. Similar things can be said with xgb as well. We found it surprising that lgb was more effective alongside catboost, considering that lgb is much less computationally expensive than xgb.
#
# Another issue I encountered was figuring which features to keep. Originally, I attempted to reduce dimensionality by eliminating features with high correlation with each other. We thought that this would address multicollinearity. However, it appeared that this was less productive than training our models (at least initially) on the entire dataset. We also though PCA might be worth our time, which is another concept we learned in STAT-362. However, we again found that this limited the success of our models.
#
# On last issue that we should point out is the reproducability our code. When going through various iterations, it was difficult to keep track of which model iterations were more successful. While we did our best to keep track of our progress, we made some mistakes regarding setting the seed of our model/data preparation at a few stages. As a result, some of our best performing models were based on models that did not have a random_state set. When reviewing the code in this report, you might find that you are getting slightly different results from ours on Kaggle. This is due to this random_state issue. We can assure that the code presented is exactly how we went about creating our best model(s), and that the variance in result is purely based on the random_state (or lack thereof) for the various steps in the model creation.

# %% [markdown]
# ## A.6) Conclusion

# %% [markdown]
# * Do you feel that you gain valuable experience, skills, and/or knowledge? If yes, please explain what they were. If no, please explain.
# * What are things you liked/disliked about the project and/or work on the project?

# %% [markdown]
# We thought that this was an incredible experience, as we had exposure to various types of models, which also forced us to think critically in order to improve our performance. The idea of collaborating within the group was also great experience, considering that most engineering jobs require strong collaboration skills. It was also incredibly rewarding to see our submissions reach the top 5 best scores, which included beating Krish's score.
#
# However, there were certainly some frustrating aspects of the project. A lot of the time, we felt like we were spinning our wheels, unable to improve our scores which were already towards the bottom of the leaderboard at the time. It was also incredibly difficult keeping track of which iterations of models/feature selection we had attempted. It was also frustrating that the two models that worked best for us weren't even ones that we had learned in any of our classes. We figured that we would have at least been exposed to the models that would provide the best shot at accomplishing a good score.

# %% [markdown]
# ## Please make sure your github repo has all the code and  ensure that your code is capable of reproducing the outcomes you have submitted. It is important to avoid any form of academic misconduct or cheating by using your peer's submission file
